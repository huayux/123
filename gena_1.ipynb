# %% [markdown]
# # Libraries

# %%
import pandas as pd
import string
import re

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
def search(dataframe: pd.DataFrame, column: string, pattern: string, useRegex = False):
    """
    Возвращает все строки из датафрейма, столбец которых содержит слово 'word'
    :param dataframe: Датафрейм, по которому ведется поиск
    :param column: Колонка датафрейма, по которой ведется поиск
    :param pattern: Искомое слово
    :param useRegex: Если хотим использовать регулярку для поиска
    :return: Датафрейм, содержащий (в себе) слово 'word' в столбдце 'column'
    """
    ret = pd.DataFrame(columns=dataframe.columns)
    for index, row in dataframe.iterrows():
        if useRegex:
            if re.match(pattern,str(row[column])):
                ret = ret.append(row)
        else:
            if str(row[column]).__contains__(pattern):
                ret = ret.append(row)
    return ret


def specSymbolsToSpace(row: str):
    """
    Для преобразования спец. символов разделителей в пробелы
    :param row: Исходная строка
    :return: Строка с пробелами вместо спец. символов
    """
    ret = row.replace('\xa0', ' ').replace('\n', ' ').replace('\t', ' ').replace('\r', ' ')
    ret = re.sub(' +', ' ', ret)
    ret = ret.strip()
    return ret

# Разделяем подозрительный список на настоящиих и 'ошибочных' актеров
def addToSet(_cast: set, _trueCast: set, word: str):
    if word in _cast:
        _trueCast.add(word)

#Необходим для чистки данных
def correctWithSor(line: str, separator = ','):
    """
    Удаление пробелов по краям фраз в строке, разделенных запятыми, в порядке возрастания с сортировкой
    :param line: Строка с фразами
    :param separator: Разделитель
    :return: Фразы, отсортированные в порядке возрастания
    """
    line = str(line).split(separator)
    ret = set()
    for word in line:
        word = str(word).strip()
        if word != '':
            ret.add(word)
    ret = sorted(list(ret))
    ret = ','.join(ret)
    return ret

#Для вывода красивого результата
def correctWithoutSor(line: str, separator = ','):
    """
    Удаление пробелов по краям фраз в строке, разделенных запятыми в порядке возрастания без сортировкой
    :param line: Строка с фразами
    :param separator: Разделитель
    :return: Фразы в изначальном порядке
    """
    line = line.split(separator)
    ret = set()
    for word in line:
        word = str(word).strip()
        if word != '':
            ret.add(word)
    ret = list(ret)
    ret = ','.join(ret)
    return ret

# %% [markdown]
# # Данные

# %% [markdown]
# Данный датасет содержит описательную информацию о 34,886 фильмах со всеми мира. Описание столбов дано ниже:
#
# * Release Year - Год выпуска фильма в прокат
# * Title - Название фильма
# * Origin/Ethnicity - Происхождение фильма (т.е. американский, болливуд и тд.)
# * Director - Режиссер(s)
# * Cast - Главные актеры
# * Genre - Жанр(ы) фильма
# * Wiki Page - URL-адрес страницы Википедии, с которой и было взято описание фильма
# * Plot - Подробное описание сюжета фильма (ВНИМАНИЕ: Может содержать спойлеры!!!)

# %%
data = pd.read_csv('wiki_movie_plots_deduped.csv')
print(f'Количество строк = ({data.shape[0]}), Количество столбцов = ({data.shape[1]})')
data.head()
# Out:
# Количество строк = (34886), Количество столбцов = (8)
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
#
#                              Director Cast    Genre  \
# 0                             Unknown  NaN  unknown
# 1                             Unknown  NaN  unknown
# 2                             Unknown  NaN  unknown
# 3                             Unknown  NaN  unknown
# 4  George S. Fleming, Edwin S. Porter  NaN  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...

# %% [markdown]
# Вводим новые столбцы, которые будем очищать

# %%
data = data.fillna('unknown')
data['DirectorCorrected'] = data['Director'].apply(lambda x: str(x).lower()).apply(lambda x: str(x).replace(' and ', ','))
data['CastCorrected'] = data['Cast'].apply(lambda x: str(x).lower()).apply(lambda x: str(x).replace(' and ', ','))
data['GenreCorrected'] = data['Genre'].apply(lambda x: str(x).lower()).apply(lambda x: str(x).replace(' and ', ','))

# %%
data.describe(include='all')
# Out:
#         Release Year       Title Origin/Ethnicity Director     Cast    Genre  \
# count   34886.000000       34886            34886    34886    34886    34886
# unique           NaN       32432               24    12593    32183     2265
# top              NaN  Cinderella         American  Unknown  unknown  unknown
# freq             NaN           8            17377     1124     1422     6083
# mean     1981.314252         NaN              NaN      NaN      NaN      NaN
# std        27.815174         NaN              NaN      NaN      NaN      NaN
# min      1901.000000         NaN              NaN      NaN      NaN      NaN
# 25%      1957.000000         NaN              NaN      NaN      NaN      NaN
# 50%      1988.000000         NaN              NaN      NaN      NaN      NaN
# 75%      2007.000000         NaN              NaN      NaN      NaN      NaN
# max      2017.000000         NaN              NaN      NaN      NaN      NaN
#
#                                                 Wiki Page  \
# count                                               34886
# unique                                              34070
# top     https://en.wikipedia.org/wiki/Digimon_Adventur...
# freq                                                    5
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      Plot DirectorCorrected  \
# count                                               34886             34886
# unique                                              33869             12564
# top     (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...           unknown
# freq                                                    6              1124
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#        CastCorrected GenreCorrected
# count          34886          34886
# unique         32180           2265
# top          unknown        unknown
# freq            1423           6083
# mean             NaN            NaN
# std              NaN            NaN
# min              NaN            NaN
# 25%              NaN            NaN
# 50%              NaN            NaN
# 75%              NaN            NaN
# max              NaN            NaN

# %% [markdown]
# Title:
#
# 1) Количество не уникальных названий = 2454. Это могут быть как повторы одного и того же фильма, так и разные фильмы с одинаковым названием. Необходимо разобраться с этим подробнее.
#
# Director:
#
# 1) Пропущенные значения ('Unknown') в Director - 1124
#
# Cast:
#
# 1) Пропущенные значения ('Unknown') в Cast - 1423
#
# Genre:
#
# 1) Пропущенные значения ('Unknown') в Genre - 6083

# %% [markdown]
# # Доп. исследования:

# %% [markdown]
# ## Жанр

# %%
genreSet = set()
for genre in data['Genre'].unique():
    words = set(genre.replace(',', ' ').replace('.', ' ').replace('-', ' ').replace('/', ' ').split(' '))
    genreSet.update(words)

', '.join(genreSet)
# Out:
# ", colour, wartime, video, priyanka, counterculture, children, boxing, aids, piece, music, bharath, physiological, pictures, citation, christian, emma, biju, aswani, slahser, event, dwayne, kids, fiction[not, rahman, ram, swashbuckler, venu, munro, shashank, r, [144], romantic, faria, cyberpunk, football, khushboo, dance, muybridge, canadian, trilogy, debut, tolani, satire, period, paul, strip, stylish, nedumudi, alice, revenge, buddy, occult, by, barua, shriya, krapiventsev, comic, cultural, the, wwii, wuxia, tragerdy, panorama, anushka, karuta), name, tóibín's, propaganda, biodrama, hegland, debashree, feature, narayan, supernatural, mazhar, entertainer, chan, martial, comedic, legend, love, psycho, live, stoker, bajwa, to, on, bouchard, cartoon, arti, sonu, rock, can, kiran, suitors, campus, bhagavaan, war, sukachenko, dram, sex, srikanth, scarlett, shraddha, films, house, south, bicycle, zombie, staged, d, gothic, deva, jr, with, pooja, dramedy, lai, home, maysuyama, jagapati, alexandre, folklore, bhoomika, w, sentiment, produced, keiji, costume, erotica, mecha, parody, zindagi, lee, studio, rajiv, comedy, mordecai, early, historic, portmanteau, stephen, ballard, nature, life, amperiani, play, malyana, donoghue, sood, jyothika, saran, from, tragedy, krishna, mockumentary, charmme, p, disaster, years, murder, vizinczey, super, michel, agarwal, legal, fantasy, laurence, priyadarshini, 1, magical, screenplay, (children's, dystopia, modern, oliver, passion, jayasudha, action—masala, board, monster, espionage, artists, sexploitation, futuristic, based, koyuki, 2, aviation, politics, production, gopi, german, horror, coming, 000, yeh, nayantara, cbc, revolutionary, huangmei, b, 16\xa0mm, bruceploitation, bernard, saali, sameera, mistry, [140], studios, kei, ken'ichi, prabhas, sexual, police, youth, khokhlova, art, sharma, about, montreal, romanctic, blaxploitation, johnson, sunil, hygiene, bhaskara, in, sergey, russell, travelogue, kothari, raj, s, kung, miniseries, poonam, post, surreal, (aquatics, viswendar, independent, allari, sumanth, (film, sivaji, triller, 25, forest, found, international, bond, [9], ravi, shakespearean, mahesh, richard, indira, road, colonial, adapted, business, harem, ago, o, serial, bros, partha, twist, menon, reality, krishnan, (volleyball), famil, satirical, nagarjuna, 6, sf, musical, gosavi's, pink, je, (fiction), photographer, romcom, national, dharma, slasher, mimi, idol, travel, social, ileana, adult, race, chakravarthy, survival, johansson, imax, opera, margaret, silent, bram, 3d, related, pioneering, prehistoric, reese, arctic, docudrama, immigrant, masala, reema, perodic, padmapriya, animation, hit, adventure, krishnashankar, cowboy, short, british, mukherjee, arya, slice, meera, humour, shenoy, united, swimming), knkspl, steampunk, loosely, motion, biblical, com, punk, ww1, slade, pic, hitler, j, of, political, ero, rajasekhar, saloni, fu, devotional, madhu, summer, vigilante, prakash, jeet, (road, lakshmana, 3, anime, directorial, comedy–drama, nadeem, sen, adventures, colm, investigative, prison, unknown, sindhu, mythology, canadiens, day, tabu, (shogi, arjun, spoof, samurai, tapas, triangle, adaptation, chiranjeevi, kondavalasa, charlie, liberation, ahlawat, masuma, korean, acclaimed, jidai, k9, madhav, raja, goyette, entertainment, nfb, uday, supeheroes, religious, cold, a, august, siva, roman, rishi, animated, family, romance;, prabhu, dvd, biography, shravan, reddy, ii, sharwanand, made, mohit, movie, documentary, fighting, (artistic), screwball, alzheimer’s, priquitianism, canada, gore, afghan, kamalinee, literary, star, suhasini, co, psy, concert, hills, oleg, comedy–horror, noir, classic, sword, exploitation, chanbara, romance, muslim, children's, genre), given], usa, brahmanandam, cinema, into, narayanan, slapstick, porno, racing), lawrence, sada, military, yakuza, compilation, space, fantay, yuen, school, rohinton, musical–comedy, action;, charmy, soldiers, mouawad's, stoner, set,  ...

# %%
"|".join(set(data['Genre'].unique()))
# Out:
# "science fiction, comedy|jeet, nusrat faria mazhar, shraddha das|action, musical|science fiction action adventure|portmanteau horror|historical/action/drama|drama, romance, musical, crime|comedy, drama, romance, musical|drama / action / romance / martial-arts|rom com/action|august 25|martial arts / action / fantasy|social drama|mahesh babu, ileana d'cruz, prakash raj|drama film|biopic, sports|biography / drama / romance|historical drama|nadeem-shravan|bio-pic, drama|world war ii/spy|adventure action comedy|action, crime, drama, adventure|comedy/romance/fantasy|comedy - thriller|bio-pic|drama / war / comedy / action|fantasy adventure comedy|comedy 2-reeler|action drama, fantasy|drama / erotic|comedy / western|tokusatsu, action, sci-fi|romance/fantasy|fantasy-comedy|action, adventure, fantasy, sci-fi|drama, war, romance, action|drama, musical|social family drama|action, crime.|horror, post-apocalyptic, steampunk, spy, action|comedy, horror, mystery|bio-pic, drama, music|drama, family, action|comedy, family film|boxing, comedy|drama / romance / history|wuxia|animated comedy|romance, crime|biography, social|action adventure, superhero|drama / musical|social children|fantasy / comedy|love|school, action, drama|drama/romance about alzheimer’s disease based on story by alice munro.|mystery, horror|pawan kalyan, reema sen, meera chopra, mukesh rishi|action-adventure, family|cartoon|horror/sci-fi|drama, comedy, action, spy, sci-fi, superheroes|neo-noir|war, science fiction|spy comedy|historical, action, military, spy, superheroes|family, drama, romance|sumanth, kamalinee mukherjee|nfb animated short|drama, children's, musical|crime, drama, thriller|drama / suspense / fantasy / costume|family, drama|crime musical|action film|historical drama / war|family social drama|fantasy drama|comedy, drama |family drama romance|drama/espionage thriller|drama based on the play by bernard slade|socio-fantasy, comedy|romance, drama, thriller|historical, comedy|drama, sci-fi, comedy, youth, slice of life|erotic comedy|epic film|keiji|action / kung fu / comedy / horror|western, biography|historical, epic|parody|dramedy, fantasy|buddy cop|science fiction adventure|politics |animated, sci-fi|action, drama, adventure, crime|comedy|historical romance|comedy / action / adventure|spy action|drama, slice of life, sports (aquatics, swimming), comedy-drama|historic|comedy, social, musical|children's science fiction|comedy/drama/action|nature|historical / drama|adventure drama|animated, comedy, drama, family|family drama|drama / romance / sci-fi|comedy/satire|satire/comedy/teen film|horror, fantasy, action, magical girl, science fantasy, spy|animation, fantasy|family, drama, sports|comedy, martial arts|action / war / adventure|drama social|romanctic comedy|sports/drama|martial arts, kung fu action|romance, sport|drama/musical|drama, mystery|romantic action|historical biopic|romance dramedy|historical, erotic|action, sci-fi|children's film|science-fiction, thriller|historical / action / war|comedy / action / mystery / crime|campus thriller|spy comedy/thriller|drama/road|dramedy, musical|muslim social|drama / romance / homosexual / family|crime fiction, drama, historical|adult/suspense/thriller|drama, silent|short animation|action, crime, thriller|spy/action/comedy|romantic triangle|romantic comedy, sports|epic, patriotism|thriller, action, romance, musical|zombie horror|action adventure thriller spy|children adventure|western, horror|action, comedy, crime, drama, romance|family, adventure|family, comedy|romance, war|comedy horror|action / romance|adventure, crime, musical, romance, thriller|world war ii/pow|action (film genre)|action / crime|romance, drama, social|animation, comedy|historical, psychological thriller, black comedy, dark fantasy, science fantasy|action, comedy, romance|drama/suspense|adventure / comedy|anthology, horror|social romance musical|fantasy, drama, dance, musical, romance, idol|animated, adult|epic western|comedy / romance / fantasy|animat ...

# %% [markdown]
# * Часть фильмов принадлежит сразу нескольким жанрам
# * Существует много различных комбинация жанров, которые необходимо как-то стандартизировать
# * Кроме самих жанров в одноименном столбце содержится всякий мусор: '(30min), 3d, usa, african etc'

# %% [markdown]
# ## Вики-страница

# %%
len(data['Wiki Page']) - len(data['Wiki Page'].unique())
# Out:
# 816

# %% [markdown]
# Есть повторяющиеся ссылки, значит часть записей повторяется

# %% [markdown]
# ## Сюжет

# %%
len(data['Plot']) - len(data['Plot'].unique())
# Out:
# 1017

# %% [markdown]
# Существуют полностью идентичные описания фильмов. Вероятнее всего, кроме существования повторяющихся ссылок, ссылки содержат и следующий недостаток: часть из них является редиректом на другие, т.к. количество уникальных описаний - 1017, а одинаковых ссылок - 816

# %% [markdown]
# ### Уникальные символы в описании

# %%
# %%time
symbols = set()
for plot in data['Plot']:
    symbols.update(set(plot))
' '.join(set(symbols))
# Out:
# CPU times: user 1.25 s, sys: 0 ns, total: 1.25 s
# Wall time: 1.28 s
# '店 犯 劍 丘 点 म ミ \u200a ź ₱ ザ N Ç Ж 坊 木 駿 ה 岡 ニ 砦 沢 夜 宗 琪 బ 野 影 ɪ 乱 厭 魚 מ स 그 薈 舌 \\ 國 二 달 â 阳 Ś 如 本 r Я м 為 熊 王 ī ま 疑 鹅 И ু ù 十 澤 碗 角 ん 庭 ɛ 銀 산 à ј ケ れ 参 爆 ё 世 ó 獄 る ệ 悟 掲 堂 Á î 半 家 仁 W l 悪 ピ 清 ĺ 幻 粉 良 教 せ 焉 ò げ 拜 流 疾 남 勇 5 军 助 ラ 望 擲 ¥ Ü 筒 | C 谷 師 ジ 大 杜 小 ヌ а レ 애 蛍 讃 池 ņ ट 輝 . 垢 異 c V ー 7 戸 d 信 腕 よ 者 姫 잎 ʾ 楓 й — 先 轩 タ 領 久 ～ ァ 々 w … с 尚 ö ø د ্ ズ > 련 \ufeff ° 方 ि » ヤ 津 シ ী 一 ð フ J ヶ ে 蓮 害 Н 全 Ż 三 カ 宙 柑 ơ 掠 द 郎 ך य テ ぶ ו ʿ 部 p 特 井 ठ ﬂ ঠ \u2009 л 麗 イ \r 州 防 ネ 中 1 ū ʃ 由 न 足 + ゲ 蓝 ½ 工 ’ 珊 ș 鎮 ம 鷗 র 四 초 ر ु 織 察 ´ ो 不 士 = 東 भ u 2 甲 塔 渋 黒 आ फ ) 奪 뽕 ゼ 言 ै 圭 岩 こ y \x92 河 b ä и Đ 賈 ا 闇 R 興 ả 首 ृ り \u200d ） ï う ь 서 艳 네 گ 0 } ē （ 猪 火 ？ ক ś 笛 仮 { 感 死 ह 血 ń र \u200b 逆 я 円 \n 高 ÷ B ほ ã 無 M 邦 柊 s 爱 合 è 龙 完 ― L 凶 μ 秀 学 水 鉱 サ ェ ひ ă 歩 オ 老 森 ற 徹 爷 弁 머 崎 マ G С 破 师 紀 鬼 軍 デ き o ư শ P 美 z ě 街 党 리 ″ 6 ム т ； ガ F 陸 ダ 里 ஆ 遊 兄 介 汤 ブ 翹 樂 聖 蛇 さ 狐 उ ス ぎ f 町 朋 k # 花 君 示 樵 商 ా 婆 渡 風 Ｗ E 杰 ← К 刀 恵 寧 李 友 海 Р \u3000 七 ‐ अ ứ 裕 八 諜 ா œ 咲 定 识 憧 沙 元 ト г m 西 グ о ² ㄜ − ʼ 葵 ल 북 铁 読 j 間 ボ す 亡 夫 꾸 バ 3 戦 鈴 場 翘 ペ 原 Ö 神 も け [ 宇 ʲ 襄 " D ⅓ ė 싹 त 수 눈 徐 ￼ 촌 록 鹿 く ャ в 武 € 伽 空 瞳 ] Š 公 ポ 別 限 ć 灯 a п H 姐 × ō t 星 コ 語 П 冯 Æ 봄 当 太 ” ச č 丹 法 綿 ण ː ゾ Ō ந 書 天 x ワ 歐 ɾ থ 灣 板 ʊ 藍 紘 ি 黄 б 署 ŏ 終 ộ 菜 ⅞ 侵 偵 ব 多 £ ý 国 汐 を ¡ 瀬 அ ソ ه ђ ル 擊 স 芳 豹 面 В ろ 盗 榮 つ 名 源 ~ İ 雨 ⁄ 澎 九 к ！ Î ₹ 草 ண 物 牢 U わ ゴ Ł 狸 é ô 切 ř ベ ₤ Č ǔ Т 春 耳 パ 桑 ュ 衛 ி ன 欧 ノ 號 翔 K 京 架 濱 椰 ê 雪 ோ ğ * _ 龍 ष 金 之 我 ế 举 都 対 A ी ू த 命 י ш 貴 É 戯 े ( ギ 尝 な ì π 連 n - 黃 藤 ŭ š д 向 鉄 穂 Ь し お セ 茶 俊 エ ţ 巫 g % च 赤 吳 黎 ा \xa0 旅 v া வ ं 務 橋 Ş 狙 丸 : た ı 山 達 電 ß ய ל T が 日 목 石 プ 尾 安 ч å ビ ீ 德 陽 Ā 婉 ষ 雄 나 探 罪 ! 夢 隊 ĩ 外 樹 ク ♥ 島 ₩ $ 光 4 ñ 田 Ț ‚ ṇ 司 青 ş 畑 · 廠 « प ধ 帝 村 Ñ あ 椿 瑞 へ ũ 府 萩 & 嘗 潛 行 I ぴ Y X æ @ 団 麻 人 ¢ ש দ р Ó 髪 ィ ロ ɡ 編 ʻ ž ġ O Q   城 ・ 泰 ы ् , ɐ 路 域 か Z 彦 竹 ज क 杭 坤 孙 馮 也 始 い í ə ッ 賢 術 S に ł ț 성 会 马 刘 民 Ŏ 乾 永 Å 魅 布 / 警 ā 生 ツ メ 湖 氏 đ h 貸 < व 祭 キ チ Г 子 ン 業 ः 真 婷 蝶 È श ¼ х க వ 図 陆 て ு ú ′ ド û 結 ग 式 話 ত 化 њ ? 乐 ḍ ब ` ங 8 妖 – 使 ; 治 走 リ み ப ゅ ц 竜 q А 年 統 響 や ü i ர 殺 á 札 刃 正 \' 林 9 ナ e 発 六 “ 手 怪 한 ‘ 的 ন 罰 予 ễ Ħ \u200c ɔ ் у ç 香 宮 ை 瑜 贝 ア の н 動 争 超 孫 ǎ 校 女 談 識 ë 魔 界 ˈ 、 月 张 モ е 千 力 条 Ž'

# %% [markdown]
# * Кроме латиницы описания содержат кириллицу и иероглифы. Веротянее всего, это оригинальные имена актеров. В дополнение к этому в описании фигурируют спец. символы вроде (\xa0 - неразрывный пробел)
# * Есть повторяющиеся описания
# * В описании присутствует не только английский язык. Возможно, это имена актеров в оригинале

# %% [markdown]
# # Графики

# %% [markdown]
# ## Год выпуска

# %%
sns.histplot(data, x='Release Year', bins=100)

# %% [markdown]
# ## Происхождение

# %%
plt.figure(figsize=(16, 8))
plt.xlabel('Origin/Ethnicity', fontsize=28)
plt.ylabel('Counts', fontsize=28)
ax = sns.countplot(data['Origin/Ethnicity'], order=pd.value_counts(data['Origin/Ethnicity']).index)
ax.set_title('Origin', fontsize=30)
plt.rc('font', size=30)
plt.xticks(rotation=90)
pass

# %% [markdown]
# # Корректировка данных
# Теперь приступим к корректировке данных

# %% [markdown]
# Для начала заменим табуляцию: перенос строки - неразрывный, пробел замением на несколько пробелов

# %%
data['Title'] = data['Title'].apply(specSymbolsToSpace)
data['Director'] = data['Director'].apply(specSymbolsToSpace)
data['Cast'] = data['Cast'].apply(specSymbolsToSpace)
data['Genre'] = data['Genre'].apply(specSymbolsToSpace)
data['Plot'] = data['Plot'].apply(specSymbolsToSpace)
data['DirectorCorrected'] = data['DirectorCorrected'].apply(specSymbolsToSpace)
data['CastCorrected'] = data['CastCorrected'].apply(specSymbolsToSpace)
data['GenreCorrected'] = data['GenreCorrected'].apply(specSymbolsToSpace)

# %% [markdown]
# ## Коррекция Вики
# Начнем с ссылок на Википедию

# %% [markdown]
# 1) Исследуем данные

# %%
def getRepeats(df:pd.DataFrame, column):
    """
    Для получения повторяющихся элементов
    :param df: Датафрейм с повторяющимися элементами
    :param column: Анализируемая строка
    :return: Датафрейм, в колонке которого есть повторы
    """
    col = df[column]
    return data.loc[list(col[col.duplicated(False)].index)]

# %%
dataRepeatsWikis = getRepeats(data, 'Wiki Page')
dataRepeatsWikis.sort_values('Wiki Page').head()
# Out:
#        Release Year        Title Origin/Ethnicity                Director  \
# 17813          2009        $9.99       Australian         Tatia Rosenthal
# 17796          2008        $9.99       Australian         Tatia Rosenthal
# 21611          2016  100 Streets          British  Director: Jim O'Hanlon
# 17168          2017  100 Streets         American            Jim O'Hanlon
# 32126          2002          123           Telugu             K. Subhaash
#
#                                                     Cast            Genre  \
# 17813  Geoffrey Rush Joel Edgerton Anthony LaPaglia C...  animation drama
# 17796       Geoffrey Rush, Joel Edgerton, Samuel Johnson        animation
# 21611  Director: Jim O'Hanlon Cast: Idris Elba, Gemma...          unknown
# 17168  Jim O'Hanlon (director); Leon F. Butler (scree...            drama
# 32126  Prabhu Deva, Jyothika, Raju Sundaram, Nagendra...           comedy
#
#                                        Wiki Page  \
# 17813        https://en.wikipedia.org/wiki/$9.99
# 17796        https://en.wikipedia.org/wiki/$9.99
# 21611  https://en.wikipedia.org/wiki/100_Streets
# 17168  https://en.wikipedia.org/wiki/100_Streets
# 32126   https://en.wikipedia.org/wiki/123_(film)
#
#                                                     Plot  \
# 17813  The film mainly focuses on 28-year-old Dave Pe...
# 17796  The film mainly focuses on 28-year-old Dave Pe...
# 21611  The film centers on three characters who have ...
# 17168  The film centers on three characters who have ...
# 32126  Tirupathi (Prabhu Deva), Pazhani (Raju Sundara...
#
#             DirectorCorrected  \
# 17813         tatia rosenthal
# 17796         tatia rosenthal
# 21611  director: jim o'hanlon
# 17168            jim o'hanlon
# 32126             k. subhaash
#
#                                            CastCorrected   GenreCorrected
# 17813  geoffrey rush joel edgerton anthony lapaglia c...  animation drama
# 17796       geoffrey rush, joel edgerton, samuel johnson        animation
# 21611  director: jim o'hanlon cast: idris elba, gemma...          unknown
# 17168  jim o'hanlon (director); leon f. butler (scree...            drama
# 32126  prabhu deva, jyothika, raju sundaram, nagendra...           comedy

# %% [markdown]
# Обратим внимание на, например, индексы 21611 и 17168 (https://en.wikipedia.org/wiki/100_Streets). У одного Жанр (Genre) указан, у второго - 'unknown'. Можно предроложить, что этот серия фильмов, а значит, жанр у них один. Редко бывает, что следующая часть фильма имеет жанр, существенно отличающийся от такого у предыдущей части

# %%
dataRepeatsWikis.loc[[21611,17168]]
# Out:
#        Release Year        Title Origin/Ethnicity                Director  \
# 21611          2016  100 Streets          British  Director: Jim O'Hanlon
# 17168          2017  100 Streets         American            Jim O'Hanlon
#
#                                                     Cast    Genre  \
# 21611  Director: Jim O'Hanlon Cast: Idris Elba, Gemma...  unknown
# 17168  Jim O'Hanlon (director); Leon F. Butler (scree...    drama
#
#                                        Wiki Page  \
# 21611  https://en.wikipedia.org/wiki/100_Streets
# 17168  https://en.wikipedia.org/wiki/100_Streets
#
#                                                     Plot  \
# 21611  The film centers on three characters who have ...
# 17168  The film centers on three characters who have ...
#
#             DirectorCorrected  \
# 21611  director: jim o'hanlon
# 17168            jim o'hanlon
#
#                                            CastCorrected GenreCorrected
# 21611  director: jim o'hanlon cast: idris elba, gemma...        unknown
# 17168  jim o'hanlon (director); leon f. butler (scree...          drama

# %% [markdown]
# 33517, 33545, 33546 (https://en.wikipedia.org/wiki/20th_Century_Boys#Films) - в отличие от предыдущих случаев на этот раз у нас трилогия фильмов, а не один и тот же фильм с продублированным названием

# %%
dataRepeatsWikis.loc[[33517,33545,33546]]
# Out:
#        Release Year                                      Title  \
# 33517          2008  20th Century Boys 1: Beginning of the End
# 33545          2009         20th Century Boys 2: The Last Hope
# 33546          2009            20th Century Boys 3: Redemption
#
#       Origin/Ethnicity           Director  \
# 33517         Japanese  Yukihiko Tsutsumi
# 33545         Japanese  Yukihiko Tsutsumi
# 33546         Japanese  Yukihiko Tsutsumi
#
#                                                     Cast  \
# 33517  Toshiaki Karasawa, Etsushi Toyokawa, Takako To...
# 33545  Toshiaki Karasawa, Etsushi Toyokawa, Takako To...
# 33546  Toshiaki Karasawa, Etsushi Toyokawa, Takako To...
#
#                           Genre  \
# 33517  science fiction, mystery
# 33545  science fiction, mystery
# 33546  science fiction, mystery
#
#                                                Wiki Page  \
# 33517  https://en.wikipedia.org/wiki/20th_Century_Boy...
# 33545  https://en.wikipedia.org/wiki/20th_Century_Boy...
# 33546  https://en.wikipedia.org/wiki/20th_Century_Boy...
#
#                                                     Plot  DirectorCorrected  \
# 33517  In 1969, young boys Kenji, Otcho, Yoshitsune a...  yukihiko tsutsumi
# 33545  In 1969, young boys Kenji, Otcho, Yoshitsune a...  yukihiko tsutsumi
# 33546  In 1969, young boys Kenji, Otcho, Yoshitsune a...  yukihiko tsutsumi
#
#                                            CastCorrected  \
# 33517  toshiaki karasawa, etsushi toyokawa, takako to...
# 33545  toshiaki karasawa, etsushi toyokawa, takako to...
# 33546  toshiaki karasawa, etsushi toyokawa, takako to...
#
#                  GenreCorrected
# 33517  science fiction, mystery
# 33545  science fiction, mystery
# 33546  science fiction, mystery

# %% [markdown]
# 32484 и 31074 (https://en.wikipedia.org/wiki/180_(2011_Tamil_film)). Фильм имеет одинаковую ссылку на Википедию, и если перейти по ней, то будет понятно, что это один и тот же фильм

# %%
dataRepeatsWikis.loc[[32484,31074]]
# Out:
#        Release Year         Title Origin/Ethnicity     Director  \
# 32484          2011           180           Telugu     Jayendra
# 31074          2011  Nootrenbadhu            Tamil  P. Jayendra
#
#                                                     Cast           Genre  \
# 32484  Siddharth, Nithya Menen, Priya Anand, Tanikell...  romantic drama
# 31074                                            unknown  romantic drama
#
#                                                Wiki Page  \
# 32484  https://en.wikipedia.org/wiki/180_(2011_Tamil_...
# 31074  https://en.wikipedia.org/wiki/180_(2011_Tamil_...
#
#                                                     Plot DirectorCorrected  \
# 32484  The movie revolves around Dr. Ajay "AJ" Kumar ...          jayendra
# 31074  The movie revolves around Dr. Ajay "AJ" Kumar ...       p. jayendra
#
#                                            CastCorrected  GenreCorrected
# 32484  siddharth, nithya menen, priya anand, tanikell...  romantic drama
# 31074                                            unknown  romantic drama

# %% [markdown]
# 17952 и 17271 (https://en.wikipedia.org/wiki/2:22_(2017_film)) -  один и тот же фильм, но с разными жанрами

# %%
dataRepeatsWikis.loc[[17952,17271]]
# Out:
#        Release Year Title Origin/Ethnicity     Director  \
# 17952          2017  2:22       Australian  Paul Currie
# 17271          2017  2:22         American  Paul Currie
#
#                                                     Cast            Genre  \
# 17952           Michiel Huisman, Teresa Palmer, Sam Reid         thriller
# 17271  Paul Currie (director); Nathan Parker, Todd St...  drama, thriller
#
#                                             Wiki Page  \
# 17952  https://en.wikipedia.org/wiki/2:22_(2017_film)
# 17271  https://en.wikipedia.org/wiki/2:22_(2017_film)
#
#                                                     Plot DirectorCorrected  \
# 17952  The movie starts with Dylan Branson (Michiel H...       paul currie
# 17271  The movie starts with Dylan Branson (Michiel H...       paul currie
#
#                                            CastCorrected   GenreCorrected
# 17952           michiel huisman, teresa palmer, sam reid         thriller
# 17271  paul currie (director); nathan parker, todd st...  drama, thriller

# %% [markdown]
# У меня есть предположение, что Plot просто дергался с Википедии и записывался в соответствующую ячейку. Если это так и описания фильмов ничем не отличаются, то можно оставлять любое

# %%
dataRepeatsWikis.groupby('Wiki Page').nunique().sort_values('Plot', ascending=False).head()
# Out:
#                                                   Release Year  Title  \
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee                   1      1
# https://en.wikipedia.org/wiki/$9.99                          2      1
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu                2      1
# https://en.wikipedia.org/wiki/Ram_Lakshman                   2      1
# https://en.wikipedia.org/wiki/Ramakrishna_(film)             2      2
#
#                                                   Origin/Ethnicity  Director  \
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee                       2         1
# https://en.wikipedia.org/wiki/$9.99                              1         1
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu                    1         2
# https://en.wikipedia.org/wiki/Ram_Lakshman                       2         2
# https://en.wikipedia.org/wiki/Ramakrishna_(film)                 2         2
#
#                                                   Cast  Genre  Plot  \
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee           2      2     2
# https://en.wikipedia.org/wiki/$9.99                  2      2     1
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu        2      1     1
# https://en.wikipedia.org/wiki/Ram_Lakshman           2      2     1
# https://en.wikipedia.org/wiki/Ramakrishna_(film)     2      2     1
#
#                                                   DirectorCorrected  \
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee                        1
# https://en.wikipedia.org/wiki/$9.99                               1
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu                     2
# https://en.wikipedia.org/wiki/Ram_Lakshman                        2
# https://en.wikipedia.org/wiki/Ramakrishna_(film)                  2
#
#                                                   CastCorrected  \
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee                    2
# https://en.wikipedia.org/wiki/$9.99                           2
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu                 2
# https://en.wikipedia.org/wiki/Ram_Lakshman                    2
# https://en.wikipedia.org/wiki/Ramakrishna_(film)              2
#
#                                                   GenreCorrected
# Wiki Page
# https://en.wikipedia.org/wiki/Nanny_McPhee                     2
# https://en.wikipedia.org/wiki/$9.99                            2
# https://en.wikipedia.org/wiki/Rakshasa_Rajavu                  1
# https://en.wikipedia.org/wiki/Ram_Lakshman                     2
# https://en.wikipedia.org/wiki/Ramakrishna_(film)               2

# %% [markdown]
# Все Вики-страницы кроме одной имеют после группировки уникальных значений в столбце Plot = 1. Осталось отдельно обработать https://en.wikipedia.org/wiki/Nanny_McPhee. Для этой страницы объединим данные через '. '

# %% [markdown]
# 2) Наметим план работы

# %% [markdown]
# Можно предложить следующее решение дублирования ссылок:
# Фильмы могут быть и многосерийными, и одним и тем же фильмом с уточнениями (жанров, актеров, директора). Можно слепить фильмы, имеющие одну и ту же ссылку на Вики-страницу по следующему принципу:
#
# 1) Год выпуска фильма берется наименьший. Если это серия фильмов, либо фильм имеет разные даты проката в разных странах, то корректнее брать наиеменьшее
#
# 2) Название идет конкатенацией через разделитель '|', мы знаем что Title не может быть пропущен. Это надо на случай различного называния фильма в разных странах
#
# 3) Происхождение объединяем черех ',' после чего удаляем повторения
#
# 4) Режиссер идет конкатенацией через ',', после чего удаляются повторения: это позволит исключить одних и тех же людей, и оставить случаи, когда над серией фильмов работали разные люди. Кроме того, так удастся уточнить часть значений 'unknown'
#
# 5) Актерский состав идет конкатенацией через ',' с удаление повторений. Такой подход позволит уточнить часть значений 'unknown'
#
# 6) Жанр идет конкатенацией через ',' с удаление повторяющихся значений. Так же по возможности уточняем 'unknown'
#
# 7) Берется одна Вики-страница
#
# 8) Сюжет - берем любое кроме https://en.wikipedia.org/wiki/Nanny_McPhee. Объединяем через '. '

# %% [markdown]
# 3) Препроцессинг Вики-страницы

# %%
def removeDuplicatesFromRepeats(df:pd.DataFrame, column):
    """
    Удаляем повторы из датарейма с повторами
    :param df: Датарейм с повторами
    :param column: Анализируемая строка
    :return: Очищенный датафрейм
    """
    return df.groupby(column).agg({
        'Release Year': lambda x: min(x),  #+
        'Title': lambda x: ','.join(x),  # Удалить повторения
        'Origin/Ethnicity': lambda x: ','.join(x),  # Удалить повторения
        'Director': lambda x: ','.join(x),  # Удалить повторения
        'Cast': lambda x: ','.join(x),  #Удалить повторения
        'Genre': lambda x: ','.join(x),  #Удалить повторения
        'Plot': lambda x: min(x),  #По сути берем любой
        'DirectorCorrected': lambda x: ','.join(x),
        'CastCorrected': lambda x: ','.join(x),
        'GenreCorrected': lambda x: ','.join(x)
    })

# %%
dataRepeatsWikis = removeDuplicatesFromRepeats(dataRepeatsWikis, 'Wiki Page')
dataRepeatsWikis.head()
# Out:
#                                                     Release Year  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                         2008
# https://en.wikipedia.org/wiki/100_Streets                   2016
# https://en.wikipedia.org/wiki/123_(film)                    2002
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...          2013
# https://en.wikipedia.org/wiki/14_Blades                     2010
#
#                                                                                 Title  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                                       $9.99,$9.99
# https://en.wikipedia.org/wiki/100_Streets                     100 Streets,100 Streets
# https://en.wikipedia.org/wiki/123_(film)                                  123,123,123
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  12 Years a Slave,12 Years a Slave
# https://en.wikipedia.org/wiki/14_Blades                           14 Blades,14 Blades
#
#                                                          Origin/Ethnicity  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                 Australian,Australian
# https://en.wikipedia.org/wiki/100_Streets                American,British
# https://en.wikipedia.org/wiki/123_(film)             Kannada,Tamil,Telugu
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...       American,British
# https://en.wikipedia.org/wiki/14_Blades                 Chinese,Hong Kong
#
#                                                                                  Director  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                       Tatia Rosenthal,Tatia Rosenthal
# https://en.wikipedia.org/wiki/100_Streets             Jim O'Hanlon,Director: Jim O'Hanlon
# https://en.wikipedia.org/wiki/123_(film)                 K. Subhash,K. Subash,K. Subhaash
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  Steve McQueen,Director: Steve McQueen
# https://en.wikipedia.org/wiki/14_Blades                    Daniel Lee Yan-Kong,Daniel Lee
#
#                                                                                                  Cast  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                 Geoffrey Rush, Joel Edgerton, Samuel Johnson,G...
# https://en.wikipedia.org/wiki/100_Streets           Jim O'Hanlon (director); Leon F. Butler (scree...
# https://en.wikipedia.org/wiki/123_(film)            Prabhu Deva, Raju Sundaram, Jyothika, Nagendra...
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  Chiwetel Ejiofor, Michael Fassbender, Benedict...
# https://en.wikipedia.org/wiki/14_Blades                     Donnie Yen, Zhao Wei,Donnie Yen, Zhao Wei
#
#                                                                              Genre  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                      animation,animation drama
# https://en.wikipedia.org/wiki/100_Streets                            drama,unknown
# https://en.wikipedia.org/wiki/123_(film)                    unknown,unknown,comedy
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...                   drama,unknown
# https://en.wikipedia.org/wiki/14_Blades             historical/action,martial arts
#
#                                                                                                  Plot  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                 The film mainly focuses on 28-year-old Dave Pe...
# https://en.wikipedia.org/wiki/100_Streets           The film centers on three characters who have ...
# https://en.wikipedia.org/wiki/123_(film)            Tirupathi (Prabhu Deva), Pazhani (Raju Sundara...
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  In 1841, Solomon Northup is a free African-Ame...
# https://en.wikipedia.org/wiki/14_Blades             During the late Ming Dynasty, the imperial cou...
#
#                                                                         DirectorCorrected  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                       tatia rosenthal,tatia rosenthal
# https://en.wikipedia.org/wiki/100_Streets             jim o'hanlon,director: jim o'hanlon
# https://en.wikipedia.org/wiki/123_(film)                 k. subhash,k. subash,k. subhaash
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  steve mcqueen,director: steve mcqueen
# https://en.wikipedia.org/wiki/14_Blades                    daniel lee yan-kong,daniel lee
#
#                                                                                         CastCorrected  \
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                 geoffrey rush, joel edgerton, samuel johnson,g...
# https://en.wikipedia.org/wiki/100_Streets           jim o'hanlon (director); leon f. butler (scree...
# https://en.wikipedia.org/wiki/123_(film)            prabhu deva, raju sundaram, jyothika, nagendra...
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...  chiwetel ejiofor, michael fassbender, benedict...
# https://en.wikipedia.org/wiki/14_Blades                     donnie yen, zhao wei,donnie yen, zhao wei
#
#                                                                     GenreCorrected
# Wiki Page
# https://en.wikipedia.org/wiki/$9.99                      animation,animation drama
# https://en.wikipedia.org/wiki/100_Streets                            drama,unknown
# https://en.wikipedia.org/wiki/123_(film)                    unknown,unknown,comedy
# https://en.wikipedia.org/wiki/12_Years_a_Slave_...                   drama,unknown
# https://en.wikipedia.org/wiki/14_Blades             historical/action,martial arts

# %%
def removeLinkFromColumn(df: pd.DataFrame, column):
    """
    Выносим данные из индекса в столбец
    """
    df[column] = df.index.copy()
    df.reset_index(drop=True, inplace=True)
    return df

# %%
dataRepeatsWikis = removeLinkFromColumn(dataRepeatsWikis, 'Wiki Page')
dataRepeatsWikis.head()
# Out:
#    Release Year                              Title       Origin/Ethnicity  \
# 0          2008                        $9.99,$9.99  Australian,Australian
# 1          2016            100 Streets,100 Streets       American,British
# 2          2002                        123,123,123   Kannada,Tamil,Telugu
# 3          2013  12 Years a Slave,12 Years a Slave       American,British
# 4          2010                14 Blades,14 Blades      Chinese,Hong Kong
#
#                                 Director  \
# 0        Tatia Rosenthal,Tatia Rosenthal
# 1    Jim O'Hanlon,Director: Jim O'Hanlon
# 2       K. Subhash,K. Subash,K. Subhaash
# 3  Steve McQueen,Director: Steve McQueen
# 4         Daniel Lee Yan-Kong,Daniel Lee
#
#                                                 Cast  \
# 0  Geoffrey Rush, Joel Edgerton, Samuel Johnson,G...
# 1  Jim O'Hanlon (director); Leon F. Butler (scree...
# 2  Prabhu Deva, Raju Sundaram, Jyothika, Nagendra...
# 3  Chiwetel Ejiofor, Michael Fassbender, Benedict...
# 4          Donnie Yen, Zhao Wei,Donnie Yen, Zhao Wei
#
#                             Genre  \
# 0       animation,animation drama
# 1                   drama,unknown
# 2          unknown,unknown,comedy
# 3                   drama,unknown
# 4  historical/action,martial arts
#
#                                                 Plot  \
# 0  The film mainly focuses on 28-year-old Dave Pe...
# 1  The film centers on three characters who have ...
# 2  Tirupathi (Prabhu Deva), Pazhani (Raju Sundara...
# 3  In 1841, Solomon Northup is a free African-Ame...
# 4  During the late Ming Dynasty, the imperial cou...
#
#                        DirectorCorrected  \
# 0        tatia rosenthal,tatia rosenthal
# 1    jim o'hanlon,director: jim o'hanlon
# 2       k. subhash,k. subash,k. subhaash
# 3  steve mcqueen,director: steve mcqueen
# 4         daniel lee yan-kong,daniel lee
#
#                                        CastCorrected  \
# 0  geoffrey rush, joel edgerton, samuel johnson,g...
# 1  jim o'hanlon (director); leon f. butler (scree...
# 2  prabhu deva, raju sundaram, jyothika, nagendra...
# 3  chiwetel ejiofor, michael fassbender, benedict...
# 4          donnie yen, zhao wei,donnie yen, zhao wei
#
#                    GenreCorrected  \
# 0       animation,animation drama
# 1                   drama,unknown
# 2          unknown,unknown,comedy
# 3                   drama,unknown
# 4  historical/action,martial arts
#
#                                            Wiki Page
# 0                https://en.wikipedia.org/wiki/$9.99
# 1          https://en.wikipedia.org/wiki/100_Streets
# 2           https://en.wikipedia.org/wiki/123_(film)
# 3  https://en.wikipedia.org/wiki/12_Years_a_Slave...
# 4            https://en.wikipedia.org/wiki/14_Blades

# %% [markdown]
# 4) Теперь удалим повторения

# %%
def removeDuplicates(df :pd.DataFrame):
    """
    Удаляем одни и те же элементы внутри одной ячейки
    :param df: Анализируемый датафрейм
    :return:
    """
    df['Title'] = df['Title'].apply(correctWithoutSor, separator=',')
    df['Origin/Ethnicity'] = df['Origin/Ethnicity'].apply(correctWithoutSor, separator=',')
    df['Director'] = df['Director'].apply(correctWithoutSor, separator=',')
    df['Cast'] = df['Cast'].apply(correctWithoutSor, separator=',')
    df['Genre'] = df['Genre'].apply(correctWithoutSor, separator=',')
    df['DirectorCorrected'] = df['DirectorCorrected'].apply(correctWithoutSor, separator=',')
    df['CastCorrected'] = df['CastCorrected'].apply(correctWithoutSor, separator=',')
    df['GenreCorrected'] = df['GenreCorrected'].apply(correctWithoutSor, separator=',')
    return df

# %%
dataRepeatsWikis = removeDuplicates(dataRepeatsWikis)

# %% [markdown]
# 5) Обновление датафрейма

# %%
def updateDataFrame(_data:pd.DataFrame, repeatsDf:pd.DataFrame, column):
    """
    Удаляем данные с повторами и добавляем очищенные. Обновляем индексы
    """
    #Удаляем индексы, соответсвующие повторяющимся элементам
    _data = _data.drop(index=_data[column][_data[column].duplicated(False)].index)
    #Добавляем откорректированные записи
    _data = _data.append(repeatsDf, ignore_index=True)
    _data = _data.reset_index()
    _data = _data.drop(columns='index')
    return _data

# %%
data = updateDataFrame(data, dataRepeatsWikis, 'Wiki Page')

# %% [markdown]
# ## Исправление названий

# %%
#Составим датафрейм с повторяющимися названиями
title = data['Title']
data.loc[list(title[title.duplicated(False)].index)].sort_values('Title').head()
# Out:
#        Release Year      Title Origin/Ethnicity          Director  \
# 32639          2014         10          Russian           Unknown
# 9425           1979         10         American     Blake Edwards
# 23266          2012  100% Love          Bengali       Rabi Kinagi
# 31054          2011  100% Love           Telugu           Sukumar
# 32545          2007         12          Russian  Nikita Mikhalkov
#
#                                                     Cast    Genre  \
# 32639                                    The Adventurers  unknown
# 9425   Dudley Moore, Julie Andrews, Bo Derek, Robert ...  unknown
# 23266                  Jeet, Koel Mallick, Supriya Dutta  romance
# 31054      Naga Chaitanya, Tamannaah Bhatia, Tara Alisha  romance
# 32545                                            unknown    crime
#
#                                                Wiki Page  \
# 32639  https://en.wikipedia.org/wiki/The_Adventurers_...
# 9425             https://en.wikipedia.org/wiki/10_(film)
# 23266  https://en.wikipedia.org/wiki/100%25_Love_(201...
# 31054  https://en.wikipedia.org/wiki/100%25_Love_(201...
# 32545       https://en.wikipedia.org/wiki/12_(2007_film)
#
#                                                     Plot DirectorCorrected  \
# 32639  Katya and Andrey arrive in Malta on the eve of...           unknown
# 9425   During a surprise 42nd birthday party for weal...     blake edwards
# 23266  Rahul (Jeet) is from a middle-class family. He...       rabi kinagi
# 31054  Balu (Naga Chaitanya) is always the top ranker...           sukumar
# 32545  The jury decides whether a young Chechen boy i...  nikita mikhalkov
#
#                                            CastCorrected GenreCorrected
# 32639                                    the adventurers        unknown
# 9425   dudley moore, julie andrews, bo derek, robert ...        unknown
# 23266                  jeet, koel mallick, supriya dutta        romance
# 31054      naga chaitanya, tamannaah bhatia, tara alisha        romance
# 32545                                            unknown          crime

# %% [markdown]
# Не имеет смысла отдельно обрабатывать схожие названия, по большому счету все фильмы являются уникальными, т.к. их описания различные

# %% [markdown]
# Можно обратить внимание на индексы 4769 и 4541: они имеют схожее описание, а Вики-страница второй - редирект с первой, но их жанры различны

# %%
data.loc[[4769,4541]]
# Out:
#       Release Year            Title Origin/Ethnicity        Director  \
# 4769          1949  Act of Violence         American  Fred Zinnemann
# 4541          1948  Act of Violence         American  Fred Zinnemann
#
#                                                   Cast      Genre  \
# 4769  Van Heflin, Robert Ryan, Janet Leigh, Mary Astor      drama
# 4541  Van Heflin, Robert Ryan, Janet Leigh, Mary Astor  film noir
#
#                                               Wiki Page  \
# 4769      https://en.wikipedia.org/wiki/Act_of_Violence
# 4541  https://en.wikipedia.org/wiki/Act_of_Violence_...
#
#                                                    Plot DirectorCorrected  \
# 4769  After surviving a Nazi POW camp where comrades...    fred zinnemann
# 4541  After surviving a Nazi POW camp where comrades...    fred zinnemann
#
#                                          CastCorrected GenreCorrected
# 4769  van heflin, robert ryan, janet leigh, mary astor          drama
# 4541  van heflin, robert ryan, janet leigh, mary astor      film noir

# %% [markdown]
# 130, 17129, 5955 - различные экранизации книги. Имеют различное описания и жанры

# %%
data.loc[[130,17129,5955]]
# Out:
#        Release Year                         Title Origin/Ethnicity  \
# 130            1916  20,000 Leagues Under the Sea         American
# 17129          1985  20,000 Leagues Under the Sea       Australian
# 5955           1954  20,000 Leagues Under the Sea         American
#
#                 Director                                               Cast  \
# 130         Stuart Paton  Lois Alexander, Curtis Benton, Wallace Clarke,...
# 17129    Tim Brooke-Hunt                                      Tom Burlinson
# 5955   Richard Fleischer  Kirk Douglas, James Mason, Paul Lukas, Peter L...
#
#                        Genre  \
# 130         action adventure
# 17129  animation / adventure
# 5955               adventure
#
#                                                Wiki Page  \
# 130    https://en.wikipedia.org/wiki/20,000_Leagues_U...
# 17129  https://en.wikipedia.org/wiki/20,000_Leagues_U...
# 5955   https://en.wikipedia.org/wiki/20,000_Leagues_U...
#
#                                                     Plot  DirectorCorrected  \
# 130    A strange giant "sea creature" has been rampag...       stuart paton
# 17129  In the year 1866, a mysterious sea-monster is ...    tim brooke-hunt
# 5955   In 1868, rumors of a sea monster attacking shi...  richard fleischer
#
#                                            CastCorrected  \
# 130    lois alexander, curtis benton, wallace clarke,...
# 17129                                      tom burlinson
# 5955   kirk douglas, james mason, paul lukas, peter l...
#
#               GenreCorrected
# 130         action adventure
# 17129  animation / adventure
# 5955               adventure

# %% [markdown]
# Решение: смотрим по описанию, если оно совпадает, то тогда объединяем две записи в одну
#
# Такой подход позволит очистить данные от редиректов

# %% [markdown]
# ## Корректируем сюжет

# %% [markdown]
# 1) Данные

# %%
dataRepeatsPlot = getRepeats(data, 'Plot')
dataRepeatsPlot.sort_values('Plot').head()
# Out:
#        Release Year                                              Title  \
# 32186          2012                                  One Piece: Film Z
# 32190          2013                                  One Piece Film: Z
# 31836          2001                         Kinnikuman Nisei the Movie
# 31858          2002  Kinnikuman Nisei: Muscle Carrot Competition! T...
# 31631          1985  Kinnikuman the Movie: Counterattack! The Under...
#
#       Origin/Ethnicity          Director  \
# 32186         Japanese  Tatsuya Nagamine
# 32190         Japanese  Tatsuya Nagamine
# 31836         Japanese           Unknown
# 31858         Japanese           Unknown
# 31631         Japanese           Unknown
#
#                                              Cast    Genre  \
# 32186  Mayumi Tanaka, Kazuya Nakai, Akemi Okamura    anime
# 32190                               Mayumi Tanaka  unknown
# 31836                                     unknown  unknown
# 31858                                     unknown  unknown
# 31631                                     unknown  unknown
#
#                                                Wiki Page  \
# 32186    https://en.wikipedia.org/wiki/One_Piece:_Film_Z
# 32190    https://en.wikipedia.org/wiki/One_Piece_Film:_Z
# 31836  https://en.wikipedia.org/wiki/Kinnikuman_Movie...
# 31858  https://en.wikipedia.org/wiki/Kinnikuman_Movie...
# 31631  https://en.wikipedia.org/wiki/Counterattack!_T...
#
#                                                     Plot DirectorCorrected  \
# 32186  "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā),...  tatsuya nagamine
# 32190  "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā),...  tatsuya nagamine
# 31836  (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...           unknown
# 31858  (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...           unknown
# 31631  (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...           unknown
#
#                                     CastCorrected GenreCorrected
# 32186  mayumi tanaka, kazuya nakai, akemi okamura          anime
# 32190                               mayumi tanaka        unknown
# 31836                                     unknown        unknown
# 31858                                     unknown        unknown
# 31631                                     unknown        unknown

# %% [markdown]
# 2) План
#
# Действуем аналогично тому, как мы поступали с Вики-страницами

# %% [markdown]
# Если описание двух фильмов совпадает при разнице в ссылках, то одна из ссылок попросту ведет на другую. Решение:
#
# 1) Год выпуска фильма берется наименьший. Если это серия фильмов, либо фильм имеет разные даты проката в разных странах, то корректнее брать наиеменьшее
#
# 2) Название идет конкатенацией через разделитель '|', мы знаем что Title не может быть пропущен. Удаляем повторы
#
# 3) Происхождение объединяем черех ',' после чего удаляем повторения
#
# 4) Режиссер идет конкатенацией через ',', после чего удаляются повторения: это позволит исключить одних и тех же людей, и оставить случаи, когда над серией фильмов работали разные люди. Кроме того, так удастся уточнить часть значений 'unknown'
#
# 5) Актерский состав идет конкатенацией через ',' с удаление повторений. Такой подход позволит уточнить часть значений 'unknown'
#
# 6) Жанр идет конкатенацией через ',' с удаление повторяющихся значений
#
# 7) Берется одна Вики-страница
#
# 8) Сюжет - берем любое

# %% [markdown]
# 3) Препроцессинг

# %%
dataRepeatsPlot = removeDuplicatesFromRepeats(dataRepeatsPlot, 'Plot')
dataRepeatsPlot.head()
# Out:
#                                                     Release Year  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...          2012
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...          1985
# 47 (Rupert Friend) is an "agent", a genetically...          2015
# A 14-year-old forlorn Kalyani delivers a boy in...          1991
# A drug bust is about to go down and Chicago cop...          1987
#
#                                                                                                 Title  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                One Piece: Film Z,One Piece Film: Z
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  Kinnikuman the Movie: Counterattack! The Under...
# 47 (Rupert Friend) is an "agent", a genetically...                          Agent 47,Hitman: Agent 47
# A 14-year-old forlorn Kalyani delivers a boy in...                               Thalapathi,Dalapathi
# A drug bust is about to go down and Chicago cop...                              Rent-a-Cop,Rent-A-Cop
#
#                                                                                      Origin/Ethnicity  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                                  Japanese,Japanese
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  Japanese,Japanese,Japanese,Japanese,Japanese,J...
# 47 (Rupert Friend) is an "agent", a genetically...                                   American,British
# A 14-year-old forlorn Kalyani delivers a boy in...                                   Bollywood,Telugu
# A drug bust is about to go down and Chicago cop...                                  American,American
#
#                                                                                            Director  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                Tatsuya Nagamine,Tatsuya Nagamine
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  Unknown,Unknown,Unknown,Unknown,Unknown,Unknown
# 47 (Rupert Friend) is an "agent", a genetically...        Aleksander Bach,Director: Aleksander Bach
# A 14-year-old forlorn Kalyani delivers a boy in...                          Mani Ratnam,Mani Ratnam
# A drug bust is about to go down and Chicago cop...                        Jerry London,Jerry London
#
#                                                                                                  Cast  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...  Mayumi Tanaka, Kazuya Nakai, Akemi Okamura,May...
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...    unknown,unknown,unknown,unknown,unknown,unknown
# 47 (Rupert Friend) is an "agent", a genetically...  Rupert Friend Zachary Quinto Hannah Ware Thoma...
# A 14-year-old forlorn Kalyani delivers a boy in...  Rajinikanth, Mammootty, Shobana,Rajinikanth, M...
# A drug bust is about to go down and Chicago cop...  Burt Reynolds, Liza Minnelli, James Remar,Burt...
#
#                                                                                               Genre  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                                    anime,unknown
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  unknown,unknown,unknown,unknown,unknown,unknown
# 47 (Rupert Friend) is an "agent", a genetically...                                   action,unknown
# A 14-year-old forlorn Kalyani delivers a boy in...                             crime, drama,unknown
# A drug bust is about to go down and Chicago cop...                               action,crime drama
#
#                                                                                                  Plot  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...  "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā),...
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...
# 47 (Rupert Friend) is an "agent", a genetically...  47 (Rupert Friend) is an "agent", a geneticall...
# A 14-year-old forlorn Kalyani delivers a boy in...  A 14-year-old forlorn Kalyani delivers a boy i...
# A drug bust is about to go down and Chicago cop...  A drug bust is about to go down and Chicago co...
#
#                                                                                   DirectorCorrected  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                tatsuya nagamine,tatsuya nagamine
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  unknown,unknown,unknown,unknown,unknown,unknown
# 47 (Rupert Friend) is an "agent", a genetically...        aleksander bach,director: aleksander bach
# A 14-year-old forlorn Kalyani delivers a boy in...                          mani ratnam,mani ratnam
# A drug bust is about to go down and Chicago cop...                        jerry london,jerry london
#
#                                                                                         CastCorrected  \
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...  mayumi tanaka, kazuya nakai, akemi okamura,may...
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...    unknown,unknown,unknown,unknown,unknown,unknown
# 47 (Rupert Friend) is an "agent", a genetically...  rupert friend zachary quinto hannah ware thoma...
# A 14-year-old forlorn Kalyani delivers a boy in...  rajinikanth, mammootty, shobana,rajinikanth, m...
# A drug bust is about to go down and Chicago cop...  burt reynolds, liza minnelli, james remar,burt...
#
#                                                                                      GenreCorrected
# Plot
# "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā), ...                                    anime,unknown
# (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chouj...  unknown,unknown,unknown,unknown,unknown,unknown
# 47 (Rupert Friend) is an "agent", a genetically...                                   action,unknown
# A 14-year-old forlorn Kalyani delivers a boy in...                             crime, drama,unknown
# A drug bust is about to go down and Chicago cop...                               action,crime drama

# %%
dataRepeatsPlot = removeLinkFromColumn(dataRepeatsPlot, 'Plot')
dataRepeatsPlot.head()
# Out:
#    Release Year                                              Title  \
# 0          2012                One Piece: Film Z,One Piece Film: Z
# 1          1985  Kinnikuman the Movie: Counterattack! The Under...
# 2          2015                          Agent 47,Hitman: Agent 47
# 3          1991                               Thalapathi,Dalapathi
# 4          1987                              Rent-a-Cop,Rent-A-Cop
#
#                                     Origin/Ethnicity  \
# 0                                  Japanese,Japanese
# 1  Japanese,Japanese,Japanese,Japanese,Japanese,J...
# 2                                   American,British
# 3                                   Bollywood,Telugu
# 4                                  American,American
#
#                                           Director  \
# 0                Tatsuya Nagamine,Tatsuya Nagamine
# 1  Unknown,Unknown,Unknown,Unknown,Unknown,Unknown
# 2        Aleksander Bach,Director: Aleksander Bach
# 3                          Mani Ratnam,Mani Ratnam
# 4                        Jerry London,Jerry London
#
#                                                 Cast  \
# 0  Mayumi Tanaka, Kazuya Nakai, Akemi Okamura,May...
# 1    unknown,unknown,unknown,unknown,unknown,unknown
# 2  Rupert Friend Zachary Quinto Hannah Ware Thoma...
# 3  Rajinikanth, Mammootty, Shobana,Rajinikanth, M...
# 4  Burt Reynolds, Liza Minnelli, James Remar,Burt...
#
#                                              Genre  \
# 0                                    anime,unknown
# 1  unknown,unknown,unknown,unknown,unknown,unknown
# 2                                   action,unknown
# 3                             crime, drama,unknown
# 4                               action,crime drama
#
#                                                 Plot  \
# 0  "Black Arm" Zephyr (黒腕のゼファー, Kokuwan no Zefā),...
# 1  (マッスル人参争奪！超人大戦争, Massuru Ninjin Soudatsu! Chou...
# 2  47 (Rupert Friend) is an "agent", a geneticall...
# 3  A 14-year-old forlorn Kalyani delivers a boy i...
# 4  A drug bust is about to go down and Chicago co...
#
#                                  DirectorCorrected  \
# 0                tatsuya nagamine,tatsuya nagamine
# 1  unknown,unknown,unknown,unknown,unknown,unknown
# 2        aleksander bach,director: aleksander bach
# 3                          mani ratnam,mani ratnam
# 4                        jerry london,jerry london
#
#                                        CastCorrected  \
# 0  mayumi tanaka, kazuya nakai, akemi okamura,may...
# 1    unknown,unknown,unknown,unknown,unknown,unknown
# 2  rupert friend zachary quinto hannah ware thoma...
# 3  rajinikanth, mammootty, shobana,rajinikanth, m...
# 4  burt reynolds, liza minnelli, james remar,burt...
#
#                                     GenreCorrected
# 0                                    anime,unknown
# 1  unknown,unknown,unknown,unknown,unknown,unknown
# 2                                   action,unknown
# 3                             crime, drama,unknown
# 4                               action,crime drama

# %% [markdown]
# 4) Удалим повторения

# %%
dataRepeatsPlot = removeDuplicates(dataRepeatsPlot)

# %% [markdown]
# 5) Объединеним данные

# %%
data = updateDataFrame(data, dataRepeatsPlot, 'Plot')

# %% [markdown]
# ## Исправляем все, что связано с людьми

# %% [markdown]
# ### Исправление жанров, актерского состава и режиссеров
# Теперь необходимо как-то стандартизировать жанры

# %% [markdown]
# #### Часть 0
# Вступление

# %%
data.shape
# Out:
# (33868, 11)

# %%
assert data.shape == (33868, 11)

# %%
data.head(10)
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
# 5          1903               Alice in Wonderland         American
# 6          1903           The Great Train Robbery         American
# 7          1904                   The Suburbanite         American
# 8          1905          The Little Train Robbery         American
# 9          1905        The Night Before Christmas         American
#
#                              Director       Cast    Genre  \
# 0                             Unknown    unknown  unknown
# 1                             Unknown    unknown  unknown
# 2                             Unknown    unknown  unknown
# 3                             Unknown    unknown  unknown
# 4  George S. Fleming, Edwin S. Porter    unknown  unknown
# 5                      Cecil Hepworth  May Clark  unknown
# 6                     Edwin S. Porter    unknown  western
# 7                  Wallace McCutcheon    unknown   comedy
# 8                Edwin Stanton Porter    unknown  unknown
# 9                Edwin Stanton Porter    unknown  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# 5  https://en.wikipedia.org/wiki/Alice_in_Wonderl...
# 6  https://en.wikipedia.org/wiki/The_Great_Train_...
# 7      https://en.wikipedia.org/wiki/The_Suburbanite
# 8  https://en.wikipedia.org/wiki/The_Little_Train...
# 9  https://en.wikipedia.org/wiki/The_Night_Before...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
# 5  Alice follows a large white rabbit down a "Rab...
# 6  The film opens with two bandits breaking into ...
# 7  The film is about a family who move to the sub...
# 8  The opening scene shows the interior of the ro...
# 9  Scenes are introduced using lines of the poem....
#
#                     DirectorCorrected CastCorrected GenreCorrected
# 0                             unknown       unknown        unknown
# 1                             unknown       unknown        unknown
# 2                             unknown       unknown        unknown
# 3                             unknown       unknown        unknown
# 4  george s. fleming, edwin s. porter       unknown        unknown
# 5                      cecil hepworth     may clark        unknown
# 6                     edwin s. porter       unknown        western
# 7                  wallace mccutcheon       unknown         comedy
# 8                edwin stanton porter       unknown        unknown
# 9                edwin stanton porter       unknown        unknown

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
pd.Series(data['GenreCorrected'].unique()).head()
# Out:
# 0                       unknown
# 1                       western
# 2                        comedy
# 3                         short
# 4    short action/crime western
# dtype: object

# %% [markdown]
# Жанры содержат в себе всякий мусор
# * drama based on the play by bernard slade
# * animated short co-produced with the national film board
# и т.д.

# %%
data.loc[2280]
# Out:
# Release Year                                                      1937
# Title                                             Think Fast, Mr. Moto
# Origin/Ethnicity                                              American
# Director                                                 Norman Foster
# Cast                          Peter Lorre, Virginia Field, Thomas Beck
# Genre                                                   drama, mystery
# Wiki Page            https://en.wikipedia.org/wiki/Think_Fast,_Mr._...
# Plot                 The film opens with Mr. Moto in disguise as a ...
# DirectorCorrected                                        norman foster
# CastCorrected                 peter lorre, virginia field, thomas beck
# GenreCorrected                                          drama, mystery
# Name: 2280, dtype: object

# %% [markdown]
# Как-то актеры (например, Uday Kiran) попали в жанр, надо их оттуда вытащить
# Идея: смотрим genre и cast, бежим по всем записям, если cast.contains(element from genre) выпихиваем элемент, выводим элемент (например, на случай существования актера, который имеет фамилию romantic)
# На всякий случай сделаем то же самое и для директора
#
# Для начала доработаем с жанрами, так мы сможем определить список различных написаний одного и того же жанра (например sci-fi, scifi и science fiction). Потом проработаем моменты с актерами и режиссерами

# %% [markdown]
# #### Часть 1
# Для начала работаем с людьми, которые попали и в жанр, и в актеров/режиссеров

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
data.loc[27353]
# Out:
# Release Year                                                      2010
# Title                                         Yogesh Dattatraya Gosavi
# Origin/Ethnicity                                               Marathi
# Director             Sandeep Kulkarni, Kishor Kadam, Neelam Shirke,...
# Cast                                                             Drama
# Genre                yogesh dattatraya gosavi's directorial debut. [9]
# Wiki Page            https://en.wikipedia.org/wiki/Pratisaad_-_The_...
# Plot                 Dr. Aditya (Sandeep Kulkarni), a leading homeo...
# DirectorCorrected    sandeep kulkarni, kishor kadam, neelam shirke,...
# CastCorrected                                                    drama
# GenreCorrected       yogesh dattatraya gosavi's directorial debut. [9]
# Name: 27353, dtype: object

# %% [markdown]
# Состав может быть перепутан с жанром
# Вероятнее, это справедливо для всех полей. Часть из них может принадлежать другим

# %% [markdown]
# Определим список актеров и режиссеров, которые попали и в соответсвующие им колонки, и в жанр. Возможно, это упростит работу в дальнейшем

# %%
def find_unique(row, separator: str):
    """
    Возвращаем уникальные записи, разделенные сепаратором + стрипим их
    @return ret = set
    """
    ret = str(row).split(separator)
    for i in range(len(ret)):
        ret[i] = ret[i].strip()
    ret = set(ret)
    ret.discard('')
    return ret

# %%
directors_set = set()
casts_set = set()
genres_set = set()
for index, row in data.iterrows():
    directors = row['DirectorCorrected'].replace('/', ',').replace('-', ',')
    directors_set.update(find_unique(directors, ','))

    casts = row['CastCorrected'].replace('/', ',').replace('-', ',')
    casts_set.update(find_unique(casts, ','))

    genres = row['GenreCorrected'].replace('/', ',').replace('-', ',')
    genres_set.update(find_unique(genres, ','))

# %%
suspicious_genres_not_pair = set()
for genre in genres_set:
    if genre != 'unknown':  #toto актуальна ли проверка?
        if genre in directors_set:
            suspicious_genres_not_pair.add(genre)
        if genre in casts_set:
            suspicious_genres_not_pair.add(genre)
print(len(suspicious_genres_not_pair))
# Out:
# 118

# %%
suspicious_genres = set()
for genre in genres_set:
    if genre != 'unknown':  #toto актуальна ли проверка?
        if genre in directors_set:
            suspicious_genres.add((genre, 'd'))
        if genre in casts_set:
            suspicious_genres.add((genre, 'c'))
print(len(suspicious_genres))
# Out:
# 137

# %% [markdown]
# Всего есть 116 записей, которые попали и в актеров/режиссеров, и в жанр. Стоит просмотреть список и удалить существующие жанры, которые попали к актерам.
# todo: до улучшения было 116! актеров

# %%
genre_list = [
    'action',
    'animated',
    'comedy',
    'crime',
    'cult',
    'drama',
    'erotic thriller',
    'family',
    'musical',
    'mystery',
    'fantasy',
    'heist',
    'historical',
    'history',
    'horror',
    'love',
    'romantic comedy',
    'romantic fantasy',
    'social',
    'sports',
    'thriller',
    'war',
    'romance',
    'suspense'  #thriller
]
len(genre_list)
# Out:
# 24

# %% [markdown]
# Обновили/сократили варианты подозрительных жанров, можно будет их выносить в имена актеров/режиссеров соответсвенно

# %%
suspicious_genres_not_pair = suspicious_genres_not_pair - set(genre_list)
len(suspicious_genres_not_pair)
# Out:
# 94

# %% [markdown]
# 94 жанров на самом деле содержат имена актеров и/или режиссеров

# %% [markdown]
# Убираем жанры, содержаие в себе режиссера и/или актеров

# %%
for index, row in data.iterrows():

    genres = row['Genre'].replace('/', ',').replace('-', ',')
    genres = find_unique(genres, ',')

    len_genres = len(genres)
    diff = genres.difference(suspicious_genres_not_pair)
    len_diff = len(diff)

    # те произошли изменения
    if len_genres != len_diff:
        for s_genre in suspicious_genres:
            if s_genre[0] in genres:
                if s_genre[1] == 'c':
                    row['CastCorrected'] = row['CastCorrected'] + ',' + s_genre[0]
                if s_genre[1] == 'd':
                    row['DirectorCorrected'] = row['DirectorCorrected'] + ',' + s_genre[0]
                genres = genres - suspicious_genres_not_pair
                row['GenreCorrected'] = ','.join(genres)

        data.iloc[index] = row

# %% [markdown]
# Теперь откорректируем названия полей

# %%
def regex(line:str):
    """
    Заменяем различные символы на ','
    :param line:
    :return:
    """
    ret = re.sub(r" */ *", ",", line)
    ret = re.sub(r" *, *", ',', ret)
    return re.sub(r" .[-–] .", ",", ret)
data['GenreCorrected'] = data['GenreCorrected'].apply(regex)

# %% [markdown]
# #### Часть 2
# Теперь работаем с людьми, которые попали только в жанр

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
data_copy = data.copy()

# %%
data = data_copy.copy()

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
data.iloc[30106]
# Out:
# Release Year                                                      1975
# Title                                              Dasari Narayana Rao
# Origin/Ethnicity                                                Telugu
# Director                                          Sobhan Babu, Sharada
# Cast                                                             Drama
# Genre                                         chakravarthy musical hit
# Wiki Page                    https://en.wikipedia.org/wiki/Balipeetham
# Plot                 Bhaskar (Shobhan Babu), a Dalit marries Aruna ...
# DirectorCorrected                                 sobhan babu, sharada
# CastCorrected                                                    drama
# GenreCorrected                                chakravarthy musical hit
# Name: 30106, dtype: object

# %%
# Чтобы слегка уменьшить код, вынесем актеров, которые не встречаются среди актеров и жанров в отдельный .txt файл
actors_txt = set()
with open("/content/actors.txt") as file:
    for line in file:
        actors_txt.add(line.replace('\n', '').strip())

# %%
# %%time
for index, row in data[:10].iterrows():
    genresCorrected = ' ' + str(row['GenreCorrected']) + ' '
    for punct in string.punctuation:
        genresCorrected = genresCorrected.replace(punct, ' ')

    for actor_txt in actors_txt:
        if genresCorrected.__contains__(' ' + actor_txt + ' '):
            print(genresCorrected, actor_txt)
            row['CastCorrected'] = row['CastCorrected'] + ',' + actor_txt
            genresCorrected = re.sub(r" *" + actor_txt + " *", ' ', genresCorrected)
            row['GenreCorrected'] = genresCorrected
            data.iloc[index] = row
# Out:
# CPU times: user 2.93 ms, sys: 0 ns, total: 2.93 ms
# Wall time: 3.15 ms

# %%
data.iloc[7:10]
# Out:
#    Release Year                       Title Origin/Ethnicity  \
# 7          1904             The Suburbanite         American
# 8          1905    The Little Train Robbery         American
# 9          1905  The Night Before Christmas         American
#
#                Director     Cast    Genre  \
# 7    Wallace McCutcheon  unknown   comedy
# 8  Edwin Stanton Porter  unknown  unknown
# 9  Edwin Stanton Porter  unknown  unknown
#
#                                            Wiki Page  \
# 7      https://en.wikipedia.org/wiki/The_Suburbanite
# 8  https://en.wikipedia.org/wiki/The_Little_Train...
# 9  https://en.wikipedia.org/wiki/The_Night_Before...
#
#                                                 Plot     DirectorCorrected  \
# 7  The film is about a family who move to the sub...    wallace mccutcheon
# 8  The opening scene shows the interior of the ro...  edwin stanton porter
# 9  Scenes are introduced using lines of the poem....  edwin stanton porter
#
#   CastCorrected GenreCorrected
# 7       unknown         comedy
# 8       unknown        unknown
# 9       unknown        unknown

# %% [markdown]
# #### Часть 3
# Очищаем от оставшегося мусора + стандартизируем жанры

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %% [markdown]
# Для этого прибегнем к следующему трюку:
# Создадим два направденных графа без циклов
# В первом жанры переходят в жанры без пробелов
# Второй же содержит более сложные конструкции
#
# Затем для каждой строки будем смотреть сложные конструкции и спличенные по пробелам, все полученные жанры - новые жанры

# %%
data.loc[7]
# Out:
# Release Year                                                      1904
# Title                                                  The Suburbanite
# Origin/Ethnicity                                              American
# Director                                            Wallace McCutcheon
# Cast                                                           unknown
# Genre                                                           comedy
# Wiki Page                https://en.wikipedia.org/wiki/The_Suburbanite
# Plot                 The film is about a family who move to the sub...
# DirectorCorrected                                   wallace mccutcheon
# CastCorrected                                                  unknown
# GenreCorrected                                                  comedy
# Name: 7, dtype: object

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
# for graphviz
# !apt install libgraphviz-dev
# !pip install pygraphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgvc6-plugins-gtk libxdot4
# 0 upgraded, 8 newly installed, 0 to remove and 20 not upgraded.
# Need to get 2,120 kB of archives.
# After this operation, 7,128 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxdot4 amd64 2.40.1-2 [15.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgvc6-plugins-gtk amd64 2.40.1-2 [18.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgraphviz-dev amd64 2.40.1-2 [57.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Fetched 2,120 kB in 2s (869 kB/s)
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libxdot4.
# Preparing to unpack .../4-libxdot4_2.40.1-2_amd64.deb ...
# Unpacking libxdot4 (2.40.1-2) ...
# Selecting previously unselected package libgvc6-plugins-gtk.
# Preparing to unpack .../5-libgvc6-plugins-gtk_2.40.1-2_amd64.deb ...
# Unpacking libgvc6-plugins-gtk (2.40.1-2) ...
# Selecting previously unselected package libgraphviz-dev.
# Preparing to unpack .../6-libgraphviz-dev_2.40.1-2_amd64.deb ...
# Unpacking libgraphviz-dev (2.40.1-2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../7-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up libxdot4 (2.40.1-2) ...
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgvc6-plugins-gtk (2.40.1-2) ...
# Setting up libgraphviz-dev (2.40.1-2) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygraphviz
#   Downloading pygraphviz-1.10.zip (120 kB)
#      |████████████████████████████████| 120 kB 4.3 MB/s
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.10-cp38-cp38-linux_x86_64.whl size=167625 sha256=cd925135bcc81c5fd6b758570089badaccb841a7842ad412f522a10e7326585b
#   Stored in directory: /root/.cache/pip/wheels/ac/bd/46/118c2a336c6fd8d47026854302f8fad63bb7e431e52008ea06
# Successfully built pygraphviz
# Installing collected packages: pygraphviz
# Successfully installed pygraphviz-1.10

# %%
import pygraphviz as pgv
from pygraphviz import *

# %%
G_simple = pgv.AGraph(strict=True, directed=True)
G_simple.add_edges_from(
    [('unknown', ' '),

     ('action', 'adventure'),

     ('survival', 'adventure'),
     ('adventures', 'adventure'),

     ('animated', 'animation'),

     ('experimental', 'art_house'),

     ('biographical', 'biography'),
     ('biopic', 'biography'),

     ('biographic', 'biography'),
     ('biogtaphy', 'biography'),
     ('biographyal', 'biography'),
     ('biodrama', 'biography'),
     ('biodrama', 'biography'),
     ('musicaliography', 'biography'),

     ("children's", 'children'),
     ('kids', 'children'),
     ('school', 'children'),

     ('stoner', 'comedy'),
     ('humour', 'comedy'),
     ('slapstick', 'comedy'),
     ('screwball', 'comedy'),
     ('comdey', 'comedy'),
     ('comedey', 'comedy'),
     ('comedic', 'comedy'),
     ('satirical', 'comedy'),
     ('satire', 'comedy'),
     ('romcom', 'comedy'),

     ('detective', 'crime'),
     ('noir', 'crime'),
     ('gangster', 'crime'),
     ('yakuza', 'crime'),
     ('outlaw', 'crime'),
     ('murder', 'crime'),
     ('police', 'crime'),
     ('prison', 'crime'),

     ('triad', 'crime'),
     ('yakuza', 'crime'),
     ('mob', 'crime'),
     ('revenge', 'crime'),
     ('blaxploitation', 'crime'),
     ('vigilante', 'crime'),

     ('docudrama', 'documentary'),
     ('mockumentary', 'documentary'),
     ('docufiction', 'documentary'),

     ('melodrama', 'drama'),
     ('shakespearean', 'drama'),
     ('exploitation', 'drama'),
     ('dramedy', 'drama'),
     ('jidaigeki', 'drama'),
     ('biodrama', 'drama'),
     ('jidaigeki', 'drama'),
     ('dram', 'drama'),
     ('dramaa', 'drama'),
     ('duology', 'drama'),
     ('docudrama', 'drama'),

     ('dramedy', 'drama'),
     ('dystopia', 'drama'),

     ('disaster', 'drama'),

     ('sexploitation', 'erotic'),
     ('sexual', 'erotic'),
     ('sex', 'erotic'),
     ('sexual', 'erotic'),
     ('porno', 'erotic'),
     ('erotictic', 'erotic'),
     ('erotictictic', 'erotic'),
     ('erotictictica', 'erotic'),
     ('sexual', 'erotic'),
     ('ero', 'erotic'),
     ('erotictica', 'erotic'),
     ('sexual', 'erotic'),
     ('homosexual', 'erotic'),
     ('sexual', 'erotic'),
     ('erotictic', 'erotic'),
     ('eroticual', 'erotic'),
     ('sexual', 'erotic'),
     ('homosexual', 'erotic'),
     ('sexploitation', 'erotic'),
     ('sexual', 'erotic'),

     ('familyy', 'family'),
     ('familyyy', 'family'),
     ('familyyya', 'family'),
     ('famil', 'family'),
     ('familya', 'family'),
     ('familyya', 'family'),

     ('fantasy', 'fiction'),
     ('zombie', 'fiction'),
     ('vampire', 'fiction'),

     ('fantay', 'fiction'),
     ('docufiction', 'fiction'),
     ('friction', 'fiction'),
     ('biblical', 'fiction'),
     ('mockumentary', 'fiction'),
     ('folklore', 'fiction'),
     ('christian', 'fiction'),

     ('futuristic', 'fiction'),
     ('religious', 'fiction'),
     ('reincarnation', 'fiction'),
     ('mecha', 'fiction'),
     ('kaiju', 'fiction'),
     ('monster', 'fiction'),
     ('mythological', 'fiction'),
     ('mythology', 'fiction'),
     ('occult', 'fiction'),
     ('supernatural', 'fiction'),

     ('mystery', 'fiction'),

     ('historical', 'history'),
     ('patriotic', 'history'),

     ('colonial', 'history'),

     ('historic', 'history'),

     ('jidaigeki', 'history'),
     ('jidaigeki', 'history'),

     ('gore', 'horror'),
     ('slasher', 'horror'),
     ('slasher', 'horror'),
     ('splatter', 'horror'),

     ('fighting', 'martial_arts'),

     ('samurai', 'martial_arts'),
     ('wuxia', 'martial_arts'),

     ('bruceploitation', 'martial_arts'),
     ('swashbuckler', 'martial_arts'),
     ('swashbuckling', 'martial_arts'),
     ('sword', 'martial_arts'),

     ('arya', 'music'),
     ('sada', 'music'),
     ('rock', 'music'),
     ('surf', 'music'),
     ('concert', 'music'),
     ('musicaliography', 'music'),

     ('operetta', 'musical'),
     ('huangmei', 'musical'),
     ('opera', 'musical'),

     ('neo_noir', 'noir'),

     ('spoof', 'parody'),

     ('psychological', 'psy'),
     ('psycho', 'psy'),

     ('love', 'romance'),

     ('romantic', 'romance'),

     ('romcom', 'romance'),

     ('romanctic', 'romance'),

     ('sci_fi', 'science_fiction'),

     ('sf', 'science_fiction'),

     ('cyberpunk', 'science_fiction'),
     ('steampunk', 'science_fiction'),

     ('chess', 'sport'),
     ('bicycle', 'sport'),
     ('racing', 'sport'),
     ('aquatics', 'sport'),
     ('swimming', 'sport'),
     ('volleyball', 'sport'),
     ('karuta', 'sport'),
     ('boxing', 'sport'),
     ('sports', 'sport'),
     ('shogi', 'sport'),
     ('chanbara', 'sport'),
     ('hockey', 'sport'),
     ('poker', 'sport'),

     ('espionage', 'spy'),

     ('super_herotices', 'super_heroes'),
     ('superherotices', 'super_heroes'),
     ('tokusatsu', 'super_heroes'),
     ('superheroes', 'super_heroes'),
     ('superhero', 'super_heroes'),

     ('superherotic', 'super_heroes'),
     ('superheroes', 'super_heroes'),

     ('student', 'teen'),
     ('school', 'teen'),
     ('youth', 'teen'),

     ('ttriller', 'thriller'),
     ('slahser', 'thriller'),
     ('thriler', 'thriller'),
     ('suspense', 'thriller'),

     ('suspense', 'thriller'),

     ('disaster', 'thriller'),
     ('triller', 'thriller'),
     ('suspense', 'thriller'),
     ('thriler', 'thriller'),

     ('wari', 'war'),
     ('ww1', 'war'),
     ('ww2', 'war'),
     ('wwii', 'war'),

     ('wartime', 'war'),
     ('military', 'war')])
G_simple.layout()
G_simple.draw('example.png', format='png')
G_simple
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7f8c65de13f0>>

# %%
G_complex = pgv.AGraph(strict=True, directed=True)
G_complex.add_edges_from([
    ('neo noir', 'noir'),
    ('period film', 'history'),
    ('period costume', 'history'),
    ('period piece', 'history'),
    ('kung fu', 'martial_arts'),
    ('martial art', 'martial_arts'),
    ('gun fu', 'martial_arts'),
    ('martial arts', 'martial_arts'),
    ('prehistoric adventure', 'adventure'),
    ('road movie', 'adventure'),
    ('buddy cop', 'crime'),
    ('disaster film', 'drama'),
    ('time travel', 'fiction'),
    ('found footage', 'fiction'),
    ('magical girl', 'fiction'),
    ('fairy tale', 'fiction'),
    ('mythology legend', 'fiction'),
    ('reincarnation suspense', 'fiction'),
    ('kaiju eiga', 'fiction'),
    ('tokusatsu v-cinema', 'super_heroes'),
    ('science fantasy', 'science_fiction'),
    ('sci fi', 'science_fiction'),
    ('american football', 'sport'),
    ('space opera', 'science_fiction'),
    ('rom com', 'romance'),
    ('rom com', 'comedy'),
    ('love story', 'romance'),
    ('romance dramedy', 'romance'),
    ('love story', 'romance'),
    ('romance suspense', 'romance'),
    ('science fiction', 'science_fiction'),
    ('spy spoof', 'spy'),
    ('coming of age', 'teen'),
    ('disaster film', 'thriller'),
    ('historical-disaster', 'thriller'),
    ('rom-com', 'romcom'),
    ('neo-noir', 'noir'),
    ('j-horror', 'horror'),
    ('historical-disaster', 'history'),
    ('pseudo-documentary', 'fiction'),
    ('socio-fantasy', 'fiction'),
    ('historical-disaster', 'drama'),
    ('bio-pic', 'biography'),
    ('time-travelling', 'fiction'),
    ('post-apocalyptic', 'fiction'),
    ('bio-drama', 'biography'),
    ('ancient-costume', 'history'),
    ('kung-fu', 'martial_arts'),
    ('martial-arts', 'martial_arts'),
    ('sci-fi', 'science_fiction'),
    ('war-time', 'war'),
    ('science-fiction', 'science_fiction'),
    ('k9 films', 'crime'),
])
G_complex.layout()
G_complex.draw('example.png', format='png')
G_complex
# Out:
# <AGraph <Swig Object of type 'Agraph_t *' at 0x7f8c659c1d80>>

# %%
def finder(G: pgv.AGraph, node):
    """
    Для графа G находим все листовые вершины для вершины node
    :Exception: -  Если граф содержит циклы
    """
    ret = set()
    visitedEdges = set()
    succesors = G.successors(node)
    if len(succesors) == 0:
        ret.add(node)
        return ret
    for q in succesors:
        newSuccesors = G.successors(q)
        if len(newSuccesors) == 0:
            # Получили цикл
            ret.add(q)
        else:
            for n in newSuccesors:
                if G.get_edge(q, n) in visitedEdges:
                    raise Exception('Граф содержит циклы')
                succesors.append(n)
                visitedEdges.add(G.get_edge(q, n))
    return ret

# %% [markdown]
# Найдем жанры для сложных графов

# %%
# список всех не листьев
vertexes = set()
for node in G_complex.nodes():
    if len(G_complex.successors(node)) != 0:
        vertexes.add(str(node))

# %%
newData = pd.DataFrame()
for index, row in data.iterrows():
    genreCorrected = row['GenreCorrected']
    res = set()
    for ver in vertexes:
        if genreCorrected.__contains__(ver):
            res.update(finder(G_complex, ver))

    row['GenreCorrected v2'] = ','.join(res)
    newData = newData.append(row, ignore_index=True)

# %%
assert newData.loc[7]['GenreCorrected'] == 'comedy'

# %% [markdown]
# Теперь найдем жанры для простых графов

# %%
#список всех вершин графа
vertexes = set()
for node in G_simple.nodes():
    vertexes.add(str(node))

# %%
newData1 = pd.DataFrame()
for index, row in newData.iterrows():
    genreCorrected = correctWithoutSor(str(row['GenreCorrected']).replace('-', ' ').replace('/', ' ').replace(',', ' ').replace('.', ' '), ' ').split(' ')
    res = set()
    for ver in vertexes:
        if ver in genreCorrected:
            res.update(finder(G_simple, ver))

    row['GenreCorrected v2'] = row['GenreCorrected v2'] + ','.join(res)
    newData1 = newData1.append(row, ignore_index=True)

# %%
data = newData1.copy()
data['GenreCorrected'] = data['GenreCorrected v2'].copy()
data = data.drop(columns=['GenreCorrected v2'])

# %%
data.head()
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0        1901.0            Kansas Saloon Smashers         American
# 1        1901.0     Love by the Light of the Moon         American
# 2        1901.0           The Martyred Presidents         American
# 3        1901.0  Terrible Teddy, the Grizzly King         American
# 4        1902.0            Jack and the Beanstalk         American
#
#                              Director     Cast    Genre  \
# 0                             Unknown  unknown  unknown
# 1                             Unknown  unknown  unknown
# 2                             Unknown  unknown  unknown
# 3                             Unknown  unknown  unknown
# 4  George S. Fleming, Edwin S. Porter  unknown  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                     DirectorCorrected CastCorrected GenreCorrected
# 0                             unknown       unknown
# 1                             unknown       unknown
# 2                             unknown       unknown
# 3                             unknown       unknown
# 4  george s. fleming, edwin s. porter       unknown

# %%
assert data.loc[7]['GenreCorrected'] == 'comedy'

# %%
len(pd.Series(data['GenreCorrected'].unique()))
# Out:
# 40

# %% [markdown]
# Получили 22 различных комбинации жанров

# %%
data.to_csv('movies_v2.csv')

# %% [markdown]
# ### Очищаем актерский состав от жанров

# %%
# Список всех node деревьев
vertexes = set()
for node in G_complex.nodes():
    vertexes.add(str(node))
for node in G_simple.nodes():
    vertexes.add(str(node))

# %%
# Находим подозрительный список актеров
data1 = pd.DataFrame(columns=data.columns)

for index, row in data.iterrows():
    casts = set(correctWithoutSor(row['CastCorrected'], separator=',').split(','))
    castSuspicious = set()
    castTrue = set()

    for cast in casts:
        for genre in vertexes:
            if re.search('[^a-zA-Z]' + genre + '[^a-zA-Z]', ' ' + cast + ' '):
                castSuspicious.add(cast)

    if len(castSuspicious) > 0:
        row['CastSuspicious'] = ','.join(castSuspicious)
        row['castTrue'] = ','.join(casts - castSuspicious)
        data1 = data1.append(row)

print(data1.shape)
data1.head()
# Out:
# (1747, 13)
#    Release Year                             Title Origin/Ethnicity  \
# 0        1901.0            Kansas Saloon Smashers         American
# 1        1901.0     Love by the Light of the Moon         American
# 2        1901.0           The Martyred Presidents         American
# 3        1901.0  Terrible Teddy, the Grizzly King         American
# 4        1902.0            Jack and the Beanstalk         American
#
#                              Director     Cast    Genre  \
# 0                             Unknown  unknown  unknown
# 1                             Unknown  unknown  unknown
# 2                             Unknown  unknown  unknown
# 3                             Unknown  unknown  unknown
# 4  George S. Fleming, Edwin S. Porter  unknown  unknown
#
#                                            Wiki Page  \
# 0  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4  https://en.wikipedia.org/wiki/Jack_and_the_Bea...
#
#                                                 Plot  \
# 0  A bartender is working at a saloon, serving dr...
# 1  The moon, painted with a smiling face hangs ov...
# 2  The film, just over a minute long, is composed...
# 3  Lasting just 61 seconds and consisting of two ...
# 4  The earliest known adaptation of the classic f...
#
#                     DirectorCorrected CastCorrected GenreCorrected  \
# 0                             unknown       unknown
# 1                             unknown       unknown
# 2                             unknown       unknown
# 3                             unknown       unknown
# 4  george s. fleming, edwin s. porter       unknown
#
#   CastSuspicious castTrue
# 0        unknown
# 1        unknown
# 2        unknown
# 3        unknown
# 4        unknown

# %%
assert data1.loc[7]['GenreCorrected'] == 'comedy'

# %%
data2 = pd.DataFrame(columns=data1.columns)
for index, row in data1.iterrows():
    casts = set(row['CastSuspicious'].split(','))
    trueCast = set(str(row['castTrue']).split(','))

    addToSet(casts, trueCast, 'the baja 1000 off-road race')
    addToSet(casts, trueCast, 'director: nick love cast: ray winstone')
    addToSet(casts, trueCast, 'sada thompson')
    addToSet(casts, trueCast, 'the dead end kids')
    addToSet(casts, trueCast, 'faizon love (voice)')
    addToSet(casts, trueCast, 'dorothy short')
    addToSet(casts, trueCast, 'bessie love.')
    addToSet(casts, trueCast, 'music by ranee lee')
    addToSet(casts, trueCast, 'the use of music against south africa under apartheid')
    addToSet(casts, trueCast, 'the east side kids')
    addToSet(casts, trueCast, 'alyson stoner')
    addToSet(casts, trueCast, 'ryan guzman briana evigan misha gabriel alyson stoner')
    addToSet(casts, trueCast, 'montagu love')
    addToSet(casts, trueCast, 'six months in the lives of five children with autism in los angeles')
    addToSet(casts, trueCast, 'susam tom and 11 children with disabilities')
    addToSet(casts, trueCast, 'ryan guzman briana evigan misha gabriel')
    addToSet(casts, trueCast, 'billy idol')
    addToSet(casts, trueCast, 'faizon love')
    addToSet(casts, trueCast, 'after a vicious attack leaves him brain-damaged and broke; mark hogancamp seeks recovery in "marwencol" a 1/6th scale world war ii-era town he creates in his backyard.')
    addToSet(casts, trueCast, 'columbus short')
    addToSet(casts, trueCast, 'drama based on a true story')
    addToSet(casts, trueCast, 'bessie love')
    addToSet(casts, trueCast, 'voices of martin short')
    addToSet(casts, trueCast, 'dead end kids')
    addToSet(casts, trueCast, 'martin short')
    addToSet(casts, trueCast, 'the murder of dilawar')
    addToSet(casts, trueCast, 'the children of prostitutes in india')
    addToSet(casts, trueCast, 'psy')
    addToSet(casts, trueCast, 'thriller manju')
    addToSet(casts, trueCast, 'courtney love')
    addToSet(casts, trueCast, 'music director- a r rahman')
    addToSet(casts, trueCast, 'jennifer love hewitt')
    addToSet(casts, trueCast, 'early pioneers of the hardcore punk music scene')
    addToSet(casts, trueCast, 'fidelity and a suburban family')
    addToSet(casts, trueCast, 'east side kids')

    row['castTrue'] = ','.join(trueCast)
    row['CastSuspicious'] = ','.join(casts - trueCast)

    data2 = data2.append(row)

# %%
data2['GenreCorrected'] = data2['GenreCorrected'] + "," + data2['CastSuspicious']
data2['CastCorrected'] = data2['CastCorrected'] + ',' + data2['castTrue']
data2 = data2.drop(columns=['CastSuspicious', 'castTrue'])

# %%
for i in data2.index:
    data.loc[i] = data2.loc[i]

# %%
data.shape
# Out:
# (33868, 11)

# %%
assert data.loc[7]['GenreCorrected'].__contains__('comedy')
assert data.loc[7]['GenreCorrected'] == 'comedy,unknown'

# %% [markdown]
# ### Очищаем режиссеров от жанров

# %%
# Находим подозрительный список актеров
data1 = pd.DataFrame(columns=data.columns)

for index, row in data.iterrows():
    casts = set(correctWithoutSor(row['DirectorCorrected'], separator=',').split(','))
    castSuspicious = set()
    castTrue = set()

    for cast in casts:
        for genre in vertexes:
            if re.search('[^a-zA-Z]' + genre + '[^a-zA-Z]', ' ' + cast + ' '):
                castSuspicious.add(cast)

    if len(castSuspicious) > 0:
        row['DirectorSuspicious'] = ','.join(castSuspicious)
        row['DirectorTrue'] = ','.join(casts - castSuspicious)
        data1 = data1.append(row)

data1.head()
# Out:
#     Release Year                             Title Origin/Ethnicity Director  \
# 0         1901.0            Kansas Saloon Smashers         American  Unknown
# 1         1901.0     Love by the Light of the Moon         American  Unknown
# 2         1901.0           The Martyred Presidents         American  Unknown
# 3         1901.0  Terrible Teddy, the Grizzly King         American  Unknown
# 14        1907.0   How Brown Saw the Baseball Game         American  Unknown
#
#        Cast    Genre                                          Wiki Page  \
# 0   unknown  unknown  https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1   unknown  unknown  https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2   unknown  unknown  https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3   unknown  unknown  https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 14  Unknown   comedy  https://en.wikipedia.org/wiki/How_Brown_Saw_th...
#
#                                                  Plot DirectorCorrected  \
# 0   A bartender is working at a saloon, serving dr...           unknown
# 1   The moon, painted with a smiling face hangs ov...           unknown
# 2   The film, just over a minute long, is composed...           unknown
# 3   Lasting just 61 seconds and consisting of two ...           unknown
# 14  Before heading out to a baseball game at a nea...           unknown
#
#    CastCorrected  GenreCorrected DirectorSuspicious DirectorTrue
# 0       unknown,        ,unknown            unknown
# 1       unknown,        ,unknown            unknown
# 2       unknown,        ,unknown            unknown
# 3       unknown,        ,unknown            unknown
# 14      unknown,  comedy,unknown            unknown

# %%
correction = data1.loc[32210]
correction
# Out:
# Release Year                                                     2010.0
# Title                                                    Цветок дьявола
# Origin/Ethnicity                                                Russian
# Director                                               Romantic fantasy
# Cast                                                            unknown
# Genre                 olga khokhlova, sergey krapiventsev, oleg suka...
# Wiki Page             https://en.wikipedia.org/wiki/The_Devil%27s_Fl...
# Plot                  The main heroine of the picture Polina is purs...
# DirectorCorrected                                      romantic fantasy
# CastCorrected                                                  unknown,
# GenreCorrected                                                 ,unknown
# DirectorSuspicious                                     romantic fantasy
# DirectorTrue
# Name: 32210, dtype: object

# %% [markdown]
# Столбец режиссеров содержит в себе жанр только в одном случае, изменим его вручную

# %%
correction = data.loc[32210]
correction['GenreCorrected'] = 'romantic,fantasy'
data.loc[32210] = correction
data.loc[32210]
# Out:
# Release Year                                                    2010.0
# Title                                                   Цветок дьявола
# Origin/Ethnicity                                               Russian
# Director                                              Romantic fantasy
# Cast                                                           unknown
# Genre                olga khokhlova, sergey krapiventsev, oleg suka...
# Wiki Page            https://en.wikipedia.org/wiki/The_Devil%27s_Fl...
# Plot                 The main heroine of the picture Polina is purs...
# DirectorCorrected                                     romantic fantasy
# CastCorrected                                                 unknown,
# GenreCorrected                                        romantic,fantasy
# Name: 32210, dtype: object

# %%
data['GenreCorrected']
# Out:
# 0         ,unknown
# 1         ,unknown
# 2         ,unknown
# 3         ,unknown
# 4         ,unknown
#            ...
# 33863     ,unknown
# 33864     ,unknown
# 33865     ,unknown
# 33866     ,unknown
# 33867     ,unknown
# Name: GenreCorrected, Length: 33868, dtype: object

# %%
assert data.loc[7]['GenreCorrected'].__contains__('comedy')
assert data.loc[7]['GenreCorrected'] == 'comedy,unknown'

# %% [markdown]
# ### Удаление мусора из актерского состава и режиссеров
# Там осталось много мусора. Можно посмотреть можно ли с этим что-то сделать

# %%
data.to_csv("1.csv")

# %% [markdown]
# ### Теперь исправим

# %% [markdown]
# #### Сначала очистим актерский состав

# %% [markdown]
# Переводим ищ актеров в режиссеры

# %%
def directorProfessionToDirector(row:str):
    return str(row).replace('screenplay','director').replace('writer','director').replace('producer','director').replace('screeplay','director').replace('director/director','director').replace('director, director','director').replace('director,director','director')
data['CastCorrected'] = data['CastCorrected'].apply(directorProfessionToDirector)

# %%
tempData = search(data, 'CastCorrected', '^directors*:', useRegex=True)
tempData.head()
# Out:
#        Release Year           Title Origin/Ethnicity  \
# 20456        2011.0  The Mirror Boy          British
# 20457        2011.0     Tyrannosaur          British
# 20458        2011.0   Late Bloomers          British
# 20459        2011.0     Chalet Girl          British
# 20460        2011.0        Ironclad          British
#
#                          Director  \
# 20456      Director: Obi Emelonye
# 20457   Director: Paddy Considine
# 20458      Director: Julie Gavras
# 20459       Director: Phil Traill
# 20460  Director: Jonathan English
#
#                                                     Cast    Genre  \
# 20456  Director: Obi Emelonye Cast: Genevieve Nnaji, ...  unknown
# 20457  Director: Paddy Considine Cast: Peter Mullan, ...  unknown
# 20458  Director: Julie Gavras Cast: William Hurt, Isa...  unknown
# 20459  Director: Phil Traill Cast: Felicity Jones, Ed...  unknown
# 20460  Director: Jonathan English Cast: Paul Giamatti...  unknown
#
#                                                Wiki Page  \
# 20456       https://en.wikipedia.org/wiki/The_Mirror_Boy
# 20457   https://en.wikipedia.org/wiki/Tyrannosaur_(film)
# 20458  https://en.wikipedia.org/wiki/Late_Bloomers_(2...
# 20459          https://en.wikipedia.org/wiki/Chalet_Girl
# 20460      https://en.wikipedia.org/wiki/Ironclad_(film)
#
#                                                     Plot  \
# 20456  The film tells the uplifting story of a young ...
# 20457  One night, unemployed widower, Joseph, drunken...
# 20458  A couple, Adam (William Hurt) and Mary (Isabel...
# 20459  Kim Mathews (Felicity Jones) is introduced by ...
# 20460  A prologue describes how the barons of England...
#
#                 DirectorCorrected  \
# 20456      director: obi emelonye
# 20457   director: paddy considine
# 20458      director: julie gavras
# 20459       director: phil traill
# 20460  director: jonathan english
#
#                                            CastCorrected GenreCorrected
# 20456  director: obi emelonye cast: genevieve nnaji, ...
# 20457  director: paddy considine cast: peter mullan, ...
# 20458  director: julie gavras cast: william hurt, isa...
# 20459  director: phil traill cast: felicity jones, ed...
# 20460  director: jonathan english cast: paul giamatti...

# %% [markdown]
# Удалили с начала строки 'directors:' или 'director:'

# %%
for index, row in tempData.iterrows():
    casts = row['CastCorrected']
    casts = casts.split('cast')
    directors = casts[0]
    directors = directors.replace('directors:', '').replace('director:', '').split(',')
    row['DirectorCorrected'] = str(row['DirectorCorrected']) + ',' + ','.join(directors)
    if len(casts) > 1:
        row['CastCorrected'] = casts[1]
    else:
        row['CastCorrected'] = ''
    tempData.loc[index] = row

# %%
assert not tempData.iloc[0]['CastCorrected'].__contains__('director')

# %%
data = data.drop(index=tempData.index)
data = data.append(tempData, ignore_index=True)
assert data.shape[0] == 33868
data
# Out:
#        Release Year                                              Title  \
# 0            1901.0                             Kansas Saloon Smashers
# 1            1901.0                      Love by the Light of the Moon
# 2            1901.0                            The Martyred Presidents
# 3            1901.0                   Terrible Teddy, the Grizzly King
# 4            1902.0                             Jack and the Beanstalk
# ...             ...                                                ...
# 33863        2013.0        The Bling Ring,Bling Ring,TheThe Bling Ring
# 33864        2014.0                           The Two Faces of January
# 33865        2011.0                                      Third Contact
# 33866        2017.0                                           Unlocked
# 33867        2014.0  The Woman in Black 2: Angel of Death,The Woman...
#
#        Origin/Ethnicity                                Director  \
# 0              American                                 Unknown
# 1              American                                 Unknown
# 2              American                                 Unknown
# 3              American                                 Unknown
# 4              American      George S. Fleming, Edwin S. Porter
# ...                 ...                                     ...
# 33863  British,American   Director: Sofia Coppola,Sofia Coppola
# 33864  British,American   Hossein Amini,Director: Hossein Amini
# 33865           British                Director: Simon Horrocks
# 33866  British,American  Directors: Michael Apted,Michael Apted
# 33867  British,American         Tom Harper,Director: Tom Harper
#
#                                                     Cast  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                                                unknown
# ...                                                  ...
# 33863  Claire Julien,Taissa Farmiga,Director: Sofia C...
# 33864  Kirsten Dunst,Oscar Isaac,Director: Hossein Am...
# 33865  Director: Simon Horrocks Tim Scott-Walker,Dire...
# 33866  Michael Douglas,Orlando Bloom,Directors: Micha...
# 33867  Jeremy Irvine,Leanne Best,Director: Tom Harper...
#
#                          Genre  \
# 0                      unknown
# 1                      unknown
# 2                      unknown
# 3                      unknown
# 4                      unknown
# ...                        ...
# 33863     unknown,comedy,crime
# 33864         unknown,thriller
# 33865                  unknown
# 33866  unknown,thriller,action
# 33867           unknown,horror
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 33863       https://en.wikipedia.org/wiki/The_Bling_Ring
# 33864  https://en.wikipedia.org/wiki/The_Two_Faces_of...
# 33865        https://en.wikipedia.org/wiki/Third_Contact
# 33866  https://en.wikipedia.org/wiki/Unlocked_(2017_f...
# 33867                                                NaN
#
#                                                     Plot  \
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 33863  Quiet teenager Marc Hall arrives as a new stud...
# 33864  In 1962, con man Chester MacFarland and his wi...
# 33865  Psychotherapist, Dr David Wright is in a sessi...
# 33866  After an operation in Paris failed on her watc...
# 33867  Forty years after the events of the first film...
#
#                                        DirectorCorrected  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                     george s. fleming, edwin s. porter
# ...                                                  ...
# 33863  director: sofia coppola,sofia coppola, sofia c...
# 33864  hossein amini,director: hossein amini, hossein...
# 33865  director: simon horrocks, simon horrocks tim s...
# 33866  michael apted,directors: michael apted, michae...
# 33867       tom harper,director: tom harper, tom harper
#
#                                            CastCorrected GenreCorrected
# 0                                               unknown,       ,unknown
# 1                                               unknown,       ,unknown
# 2                                               unknown,       ,unknown
# 3                                               unknown,       ,unknown
# 4                                               unknown,       ,unknown
# ...                                                  ...            ...
# 33863  : israel broussard,katie chang,claire julien,g...  ,georgia rock
# 33864  : viggo mortensen,oscar isaac,kirsten dunst,vi...
# 33865
# 33866  : noomi rapace,orlando bloom,jessica boone,mic...
# 33867  : phoebe fox,adrian rawlins,leanne best,phoebe...
#
# [33868 rows x 11 columns]

# %%
assert data.loc[7]['GenreCorrected'].__contains__('comedy')
assert data.loc[7]['GenreCorrected'] == 'comedy,unknown'

# %%
tempData = search(data, 'CastCorrected', 'director', useRegex=False)
tempData
# Out:
#        Release Year                                        Title  \
# 13341        2000.0               Book of Shadows: Blair Witch 2
# 16716        2017.0                       Underworld: Blood Wars
# 16717        2017.0                               Monster Trucks
# 16718        2017.0                              The Bye Bye Man
# 16719        2017.0                                    Sleepless
# ...             ...                                          ...
# 33507        2012.0                                  The Sweeney
# 33557        2013.0                                  Hummingbird
# 33607        2013.0                                 Nymphomaniac
# 33863        2013.0  The Bling Ring,Bling Ring,TheThe Bling Ring
# 33866        2017.0                                     Unlocked
#
#        Origin/Ethnicity                                Director  \
# 13341          American                           Joe Berlinger
# 16716          American                           Anna Foerster
# 16717          American                             Chris Wedge
# 16718          American                             Stacy Title
# 16719          American                           Baran bo Odar
# ...                 ...                                     ...
# 33507           British                     Director: Nick Love
# 33557           British                 Director: Steven Knight
# 33607           British                Director: Lars von Trier
# 33863  British,American   Director: Sofia Coppola,Sofia Coppola
# 33866  British,American  Directors: Michael Apted,Michael Apted
#
#                                                     Cast  \
# 13341      Kim Director, Jeffrey Donovan, Erica Leerhsen
# 16716  Anna Foerster (director); Cory Goodman (screen...
# 16717  Chris Wedge (director); Jonathan Aibel, Glenn ...
# 16718  Stacy Title (director); Jonathan Penner (scree...
# 16719  Baran bo Odar (director); Andrea Berloff (scre...
# ...                                                  ...
# 33507  Director: Nick Love Cast: Ray Winstone, Ben Dr...
# 33557  Director: Steven Knight Cast: Jason Statham, A...
# 33607  Director: Lars von Trier Cast: Charlotte Gains...
# 33863  Claire Julien,Taissa Farmiga,Director: Sofia C...
# 33866  Michael Douglas,Orlando Bloom,Directors: Micha...
#
#                               Genre  \
# 13341                        horror
# 16716                action, horror
# 16717  animation, adventure, sci-fi
# 16718                        horror
# 16719              action, thriller
# ...                             ...
# 33507                       unknown
# 33557                       unknown
# 33607                       unknown
# 33863          unknown,comedy,crime
# 33866       unknown,thriller,action
#
#                                                Wiki Page  \
# 13341  https://en.wikipedia.org/wiki/Book_of_Shadows:...
# 16716  https://en.wikipedia.org/wiki/Underworld:_Bloo...
# 16717  https://en.wikipedia.org/wiki/Monster_Trucks_(...
# 16718      https://en.wikipedia.org/wiki/The_Bye_Bye_Man
# 16719  https://en.wikipedia.org/wiki/Sleepless_(2017_...
# ...                                                  ...
# 33507  https://en.wikipedia.org/wiki/The_Sweeney_(201...
# 33557   https://en.wikipedia.org/wiki/Hummingbird_(film)
# 33607  https://en.wikipedia.org/wiki/Nymphomaniac_(film)
# 33863       https://en.wikipedia.org/wiki/The_Bling_Ring
# 33866  https://en.wikipedia.org/wiki/Unlocked_(2017_f...
#
#                                                     Plot  \
# 13341  In November 1999, tourists and fans of The Bla...
# 16716  The remaining vampire covens are on the verge ...
# 16717  Terravex Oil is in the midst of a fracking ope...
# 16718  In 1969, a mass murder occurs in which a man k...
# 16719  In Las Vegas, vice LVMPD policemen Vincent Dow...
# ...                                                  ...
# 33507  Flying Squad officers Detective Inspector Jack...
# 33557  Joseph Smith is a former Special Forces soldie...
# 33607  On a snowy evening, middle-aged bachelor Selig...
# 33863  Quiet teenager Marc Hall arrives as a new stud...
# 33866  After an operation in Paris failed on her watc...
#
#                                        DirectorCorrected  \
# 13341                                      joe berlinger
# 16716                                      anna foerster
# 16717                                        chris wedge
# 16718                                        stacy title
# 16719                                      baran bo odar
# ...                                                  ...
# 33507                    director: nick love, nick love
# 33557            director: steven knight, steven knight
# 33607          director: lars von trier, lars von trier
# 33863  director: sofia coppola,sofia coppola, sofia c...
# 33866  michael apted,directors: michael apted, michae...
#
#                                            CastCorrected  \
# 13341      kim director, jeffrey donovan, erica leerhsen
# 16716  anna foerster (director); cory goodman (direct...
# 16717  chris wedge (director); jonathan aibel, glenn ...
# 16718  stacy title (director); jonathan penner (direc...
# 16719  baran bo odar (director); andrea berloff (dire...
# ...                                                  ...
# 33507  : ray winstone, ben drew, jeremy clarkson,ben ...
# 33557  : jason statham, agata buzek, christian brassi...
# 33607  : charlotte gainsbourg, stellan skarsgård, sta...
# 33863  : israel broussard,katie chang,claire julien,g...
# 33866  : noomi rapace,orlando bloom,jessica boone,mic...
#
#                 GenreCorrected
# 13341                   horror
# 16716
# 16717          science_fiction
# 16718                   horror
# 16719
# ...                        ...
# 33507                        ,
# 33557   ,christian brassington
# 33607        ,christian slater
# 33863            ,georgia rock
# 33866
#
# [412 rows x 11 columns]

# %%
for index, row in tempData.iterrows():
    casts = row['CastCorrected'].replace(';',',').split(',')
    notDirector = set()
    for cast in casts:
        if cast.__contains__('director'):
            row['DirectorCorrected'] = row['DirectorCorrected'] + ',' + cast.replace('director','')
        else:
            notDirector.add(cast)
    row['CastCorrected'] = ','.join(notDirector)
    tempData.loc[index] = row

# %%
assert not tempData.iloc[0]['CastCorrected'].__contains__('director')

# %%
data = data.drop(index=tempData.index)
data = data.append(tempData, ignore_index=True)
assert data.shape[0] == 33868
data
# Out:
#        Release Year                                        Title  \
# 0            1901.0                       Kansas Saloon Smashers
# 1            1901.0                Love by the Light of the Moon
# 2            1901.0                      The Martyred Presidents
# 3            1901.0             Terrible Teddy, the Grizzly King
# 4            1902.0                       Jack and the Beanstalk
# ...             ...                                          ...
# 33863        2012.0                                  The Sweeney
# 33864        2013.0                                  Hummingbird
# 33865        2013.0                                 Nymphomaniac
# 33866        2013.0  The Bling Ring,Bling Ring,TheThe Bling Ring
# 33867        2017.0                                     Unlocked
#
#        Origin/Ethnicity                                Director  \
# 0              American                                 Unknown
# 1              American                                 Unknown
# 2              American                                 Unknown
# 3              American                                 Unknown
# 4              American      George S. Fleming, Edwin S. Porter
# ...                 ...                                     ...
# 33863           British                     Director: Nick Love
# 33864           British                 Director: Steven Knight
# 33865           British                Director: Lars von Trier
# 33866  British,American   Director: Sofia Coppola,Sofia Coppola
# 33867  British,American  Directors: Michael Apted,Michael Apted
#
#                                                     Cast  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                                                unknown
# ...                                                  ...
# 33863  Director: Nick Love Cast: Ray Winstone, Ben Dr...
# 33864  Director: Steven Knight Cast: Jason Statham, A...
# 33865  Director: Lars von Trier Cast: Charlotte Gains...
# 33866  Claire Julien,Taissa Farmiga,Director: Sofia C...
# 33867  Michael Douglas,Orlando Bloom,Directors: Micha...
#
#                          Genre  \
# 0                      unknown
# 1                      unknown
# 2                      unknown
# 3                      unknown
# 4                      unknown
# ...                        ...
# 33863                  unknown
# 33864                  unknown
# 33865                  unknown
# 33866     unknown,comedy,crime
# 33867  unknown,thriller,action
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 33863  https://en.wikipedia.org/wiki/The_Sweeney_(201...
# 33864   https://en.wikipedia.org/wiki/Hummingbird_(film)
# 33865  https://en.wikipedia.org/wiki/Nymphomaniac_(film)
# 33866       https://en.wikipedia.org/wiki/The_Bling_Ring
# 33867  https://en.wikipedia.org/wiki/Unlocked_(2017_f...
#
#                                                     Plot  \
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 33863  Flying Squad officers Detective Inspector Jack...
# 33864  Joseph Smith is a former Special Forces soldie...
# 33865  On a snowy evening, middle-aged bachelor Selig...
# 33866  Quiet teenager Marc Hall arrives as a new stud...
# 33867  After an operation in Paris failed on her watc...
#
#                                        DirectorCorrected  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                     george s. fleming, edwin s. porter
# ...                                                  ...
# 33863       director: nick love, nick love ,: nick love
# 33864  director: steven knight, steven knight ,: stev...
# 33865  director: lars von trier, lars von trier ,: la...
# 33866  director: sofia coppola,sofia coppola, sofia c...
# 33867  michael apted,directors: michael apted, michae...
#
#                                            CastCorrected  \
# 0                                               unknown,
# 1                                               unknown,
# 2                                               unknown,
# 3                                               unknown,
# 4                                               unknown,
# ...                                                  ...
# 33863  ben drew, ben drew,jeremy clarkson,: ray winst...
# 33864   benedict wong, vicky mcclure,: jason statham,...
# 33865   christian slater,mia goth,udo kier, shia labe...
# 33866  katie chang,claire julien,georgia rock,israel ...
# 33867  : noomi rapace, noomi rapace,orlando bloom,jes...
#
#                 GenreCorrected
# 0                     ,unknown
# 1                     ,unknown
# 2                     ,unknown
# 3                     ,unknown
# 4                     ,unknown
# ...                        ...
# 33863                        ,
# 33864   ,christian brassington
# 33865        ,christian slater
# 33866            ,georgia rock
# 33867
#
# [33868 rows x 11 columns]

# %%
assert data.loc[7]['GenreCorrected'].__contains__('comedy')
assert data.loc[7]['GenreCorrected'] == 'comedy,unknown'

# %% [markdown]
# Bеперь избавимся от 'voice'

# %%
data['CastCorrected'] = data['CastCorrected'].apply(lambda x:  x.replace('voices', '').replace('voice', ''))

# %% [markdown]
# теперь от скобочек

# %%
tempData = search(data, 'CastCorrected', '(', useRegex=False)
tempData
# Out:
#        Release Year                                         Title  \
# 1997         1936.0                               Anthony Adverse
# 2020         1936.0                               Come and Get It
# 2028         1936.0                                     Dodsworth
# 2049         1936.0                            The Great Ziegfeld
# 2079         1936.0                        Mr. Deeds Goes to Town
# ...             ...                                           ...
# 32869        1991.0  Beauty and the Beast 3D,Beauty and the Beast
# 33382        2017.0                            Don't Take Me Home
# 33450        2011.0                                          Paul
# 33509        2017.0                                 Born in China
# 33528        2017.0                                   War Machine
#
#        Origin/Ethnicity                                     Director  \
# 1997           American                                 Mervyn LeRoy
# 2020           American                  Howard Hawks, William Wyler
# 2028           American          William Wyler Best Director nominee
# 2049           American      Robert Z. Leonard Best Director nominee
# 2079           American  Frank Capra Academy Award for Best Director
# ...                 ...                                          ...
# 32869          American                     Gary Trousdale,Kirk Wise
# 33382           British                         Director: Jonny Owen
# 33450  British,American          Director: Greg Mottola,Greg Mottola
# 33509          American                                     Lu Chuan
# 33528          American                                 David Michôd
#
#                                                     Cast  \
# 1997   Fredric March, Olivia de Havilland, Donald Woo...
# 2020   Edward Arnold, Joel McCrea, Frances Farmer, Wa...
# 2028   Walter Huston (Best Actor nominee), Ruth Chatt...
# 2049   William Powell, Myrna Loy, Luise Rainer (Acade...
# 2079   Gary Cooper (Best Actor nominee), Jean Arthur,...
# ...                                                  ...
# 32869  Jo Anne Worley,Hal Smith,Jerry Orbach,Angela L...
# 33382  Director: Jonny Owen Cast: Gareth Bale, Chris ...
# 33450  Seth Rogen (voice),Bill Hader,Simon Pegg,Jane ...
# 33509  Lu Chuan (director); David Fowler (screenplay)...
# 33528  David Michôd (director/screenplay); Michael Ha...
#
#                          Genre  \
# 1997            drama, romance
# 2020                     drama
# 2028                     drama
# 2049         musical biography
# 2079           comedy, romance
# ...                        ...
# 32869  family,fantasy,animated
# 33382                  unknown
# 33450    unknown,sci-fi comedy
# 33509              documentary
# 33528       comedy, drama, war
#
#                                                Wiki Page  \
# 1997       https://en.wikipedia.org/wiki/Anthony_Adverse
# 2020   https://en.wikipedia.org/wiki/Come_and_Get_It_...
# 2028      https://en.wikipedia.org/wiki/Dodsworth_(film)
# 2049    https://en.wikipedia.org/wiki/The_Great_Ziegfeld
# 2079   https://en.wikipedia.org/wiki/Mr._Deeds_Goes_t...
# ...                                                  ...
# 32869                                                NaN
# 33382  https://en.wikipedia.org/wiki/Don%27t_Take_Me_...
# 33450          https://en.wikipedia.org/wiki/Paul_(film)
# 33509        https://en.wikipedia.org/wiki/Born_in_China
# 33528   https://en.wikipedia.org/wiki/War_Machine_(film)
#
#                                                     Plot  \
# 1997   In 1773, young English beauty Maria Bonnyfeath...
# 2020   Ruthless lumberjack foreman Barney Glasgow (Ed...
# 2028   In the Midwestern town of Zenith, Samuel "Sam"...
# 2049   The son of a highly respected music professor,...
# 2079   During the Great Depression, Longfellow Deeds ...
# ...                                                  ...
# 32869  One winter's night, an enchantress disguised a...
# 33382  The film recounts the saga of Wales national f...
# 33450  Graeme Willy and Clive Gollings are British co...
# 33509  This documentary follows four individual anima...
# 33528  In the summer of 2009, four-star General Glen ...
#
#                                        DirectorCorrected  \
# 1997                                        mervyn leroy
# 2020                         howard hawks, william wyler
# 2028                 william wyler best director nominee
# 2049             robert z. leonard best director nominee
# 2079         frank capra academy award for best director
# ...                                                  ...
# 32869                           kirk wise,gary trousdale
# 33382                  director: jonny owen, jonny owen
# 33450  director: greg mottola,greg mottola, greg mott...
# 33509              lu chuan,lu chuan (), david fowler ()
# 33528                       david michôd,david michôd ()
#
#                                            CastCorrected   GenreCorrected
# 1997   fredric march, olivia de havilland, donald woo...
# 2020   edward arnold, joel mccrea, frances farmer, wa...            drama
# 2028   walter huston (best actor nominee), ruth chatt...            drama
# 2049   william powell, myrna loy, luise rainer (acade...
# 2079   gary cooper (best actor nominee), jean arthur,...
# ...                                                  ...              ...
# 32869  angela lansbury,jo anne worley,bradley pierce,...
# 33382  : gareth bale, chris coleman, aaron ramsey, ga...
# 33450  : simon pegg,simon pegg,jeffrey tambor,jane ly...  science_fiction
# 33509                zhou xun (narrator), john krasinski      documentary
# 33528   michael hastings (book), john magaro, alan ru...
#
# [115 rows x 11 columns]

# %%
for index, row in tempData.iterrows():
    casts = row['CastCorrected'].split(',')
    normalCast = set()
    for cast in casts:
        if cast.__contains__('('):
            row['DirectorCorrected'] = row['DirectorCorrected'] + ',' +re.sub('\([\d\w ]*\)', '', cast)
        else:
            normalCast.add(cast)
    row['CastCorrected'] = ','.join(normalCast)
    tempData.loc[index] = row

# %%
data = data.drop(index=tempData.index)
data = data.append(tempData, ignore_index=True)
assert data.shape[0] == 33868
data
# Out:
#        Release Year                                         Title  \
# 0            1901.0                        Kansas Saloon Smashers
# 1            1901.0                 Love by the Light of the Moon
# 2            1901.0                       The Martyred Presidents
# 3            1901.0              Terrible Teddy, the Grizzly King
# 4            1902.0                        Jack and the Beanstalk
# ...             ...                                           ...
# 33863        1991.0  Beauty and the Beast 3D,Beauty and the Beast
# 33864        2017.0                            Don't Take Me Home
# 33865        2011.0                                          Paul
# 33866        2017.0                                 Born in China
# 33867        2017.0                                   War Machine
#
#        Origin/Ethnicity                             Director  \
# 0              American                              Unknown
# 1              American                              Unknown
# 2              American                              Unknown
# 3              American                              Unknown
# 4              American   George S. Fleming, Edwin S. Porter
# ...                 ...                                  ...
# 33863          American             Gary Trousdale,Kirk Wise
# 33864           British                 Director: Jonny Owen
# 33865  British,American  Director: Greg Mottola,Greg Mottola
# 33866          American                             Lu Chuan
# 33867          American                         David Michôd
#
#                                                     Cast  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                                                unknown
# ...                                                  ...
# 33863  Jo Anne Worley,Hal Smith,Jerry Orbach,Angela L...
# 33864  Director: Jonny Owen Cast: Gareth Bale, Chris ...
# 33865  Seth Rogen (voice),Bill Hader,Simon Pegg,Jane ...
# 33866  Lu Chuan (director); David Fowler (screenplay)...
# 33867  David Michôd (director/screenplay); Michael Ha...
#
#                          Genre  \
# 0                      unknown
# 1                      unknown
# 2                      unknown
# 3                      unknown
# 4                      unknown
# ...                        ...
# 33863  family,fantasy,animated
# 33864                  unknown
# 33865    unknown,sci-fi comedy
# 33866              documentary
# 33867       comedy, drama, war
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 33863                                                NaN
# 33864  https://en.wikipedia.org/wiki/Don%27t_Take_Me_...
# 33865          https://en.wikipedia.org/wiki/Paul_(film)
# 33866        https://en.wikipedia.org/wiki/Born_in_China
# 33867   https://en.wikipedia.org/wiki/War_Machine_(film)
#
#                                                     Plot  \
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 33863  One winter's night, an enchantress disguised a...
# 33864  The film recounts the saga of Wales national f...
# 33865  Graeme Willy and Clive Gollings are British co...
# 33866  This documentary follows four individual anima...
# 33867  In the summer of 2009, four-star General Glen ...
#
#                                        DirectorCorrected  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                     george s. fleming, edwin s. porter
# ...                                                  ...
# 33863          kirk wise,gary trousdale,angela lansbury
# 33864     director: jonny owen, jonny owen , gary speed
# 33865  director: greg mottola,greg mottola, greg mott...
# 33866   lu chuan,lu chuan (), david fowler (), zhou xun
# 33867    david michôd,david michôd (), michael hastings
#
#                                            CastCorrected   GenreCorrected
# 0                                               unknown,         ,unknown
# 1                                               unknown,         ,unknown
# 2                                               unknown,         ,unknown
# 3                                               unknown,         ,unknown
# 4                                               unknown,         ,unknown
# ...                                                  ...              ...
# 33863  angela lansbury,rex everhart,paige o'hara,davi...
# 33864   aaron ramsey, ashley williams, chris coleman,...
# 33865  simon pegg,nick frost,jeffrey tambor,jane lync...  science_fiction
# 33866                                     john krasinski      documentary
# 33867   will poulter, john magaro, alan ruck, anthony...
#
# [33868 rows x 11 columns]

# %% [markdown]
# #### Теперь почистим режиссеров

# %% [markdown]
# director: ... cast:

# %%
tempData = search(data, 'DirectorCorrected', 'cast:', useRegex=False)
tempData
# Out:
#        Release Year                                              Title  \
# 33616        2016.0                                        100 Streets
# 33617        2013.0                                   12 Years a Slave
# 33619        2017.0                                     47 Meters Down
# 33620        2011.0                                     A Few Best Men
# 33621        2016.0                                 A Monster Calls,23
# ...             ...                                                ...
# 33740        2011.0  Harry Potter and the Deathly Hallows: Part 2,H...
# 33741        2010.0                        Perfect Sense,The Last Word
# 33742        2012.0                              The Expatriate,Erased
# 33743        2011.0                  Gnomeo and Juliet,Gnomeo & Juliet
# 33745        2017.0                    Gurinder Chadha,Viceroy's House
#
#          Origin/Ethnicity                                           Director  \
# 33616    British,American                Jim O'Hanlon,Director: Jim O'Hanlon
# 33617    British,American              Steve McQueen,Director: Steve McQueen
# 33619    British,American        Johannes Roberts,Director: Johannes Roberts
# 33620  British,Australian          Stephan Elliott,Director: Stephan Elliott
# 33621    British,American             A Monster Calls,Director: J. A. Bayona
# ...                   ...                                                ...
# 33740    British,American                  David Yates,Director: David Yates
# 33741             British          David Mackenzie,Director: David Mackenzie
# 33742    British,American            Philipp Stölzl,Director: Philipp Stölzl
# 33743    British,American                Kelly Asbury,Director: Kelly Asbury
# 33745   British,Bollywood  Manish Dayal,Huma Qureshi,Michael Gambon,Hugh ...
#
#                                                     Cast  \
# 33616  Charlie Creed-Miles,Ken Stott,Tom Cullen,Jim O...
# 33617  Paul Giamatti,Michael Fassbender,Alfre Woodard...
# 33619  Matthew Modine,Santiago Segura,Mandy Moore,Cla...
# 33620  Kris Marshall,Director: Stephan Elliott Cast: ...
# 33621  Director: J. A. Bayona Cast: Lewis MacDougall,...
# ...                                                  ...
# 33740  Robbie Coltrane,John Hurt,Julie Walters,Fiona ...
# 33741  Director: David Mackenzie Cast: Eva Green,Eva ...
# 33742  Aaron Eckhart,Garrick Hagon,Alexander Fehling,...
# 33743  Hulk Hogan,Maggie Smith,Emily Blunt,Matt Lucas...
# 33745  Manish Dayal,Huma Qureshi,Drama,David Hayman,D...
#
#                                   Genre  \
# 33616                     unknown,drama
# 33617                     unknown,drama
# 33619                    unknown,horror
# 33620                    unknown,comedy
# 33621                           unknown
# ...                                 ...
# 33740  action-adventure,unknown,fantasy
# 33741                           unknown
# 33742                  unknown,thriller
# 33743           unknown,family,animated
# 33745                 unknown,bbc films
#
#                                                Wiki Page  \
# 33616          https://en.wikipedia.org/wiki/100_Streets
# 33617  https://en.wikipedia.org/wiki/12_Years_a_Slave...
# 33619       https://en.wikipedia.org/wiki/47_Meters_Down
# 33620       https://en.wikipedia.org/wiki/A_Few_Best_Men
# 33621  https://en.wikipedia.org/wiki/A_Monster_Calls_...
# ...                                                  ...
# 33740                                                NaN
# 33741                                                NaN
# 33742                                                NaN
# 33743                                                NaN
# 33745                                                NaN
#
#                                                     Plot  \
# 33616  The film centers on three characters who have ...
# 33617  In 1841, Solomon Northup is a free African-Ame...
# 33619  Lisa (Mandy Moore) and Kate (Claire Holt) are ...
# 33620  When David Locking (Samuel) proposes to his gi...
# 33621  Twelve-year-old Connor O'Malley must face his ...
# ...                                                  ...
# 33740  After burying Dobby, Harry Potter asks the gob...
# 33741  An epidemic begins to spread throughout the gl...
# 33742  Ben Logan is an American single parent who has...
# 33743  In Stratford-Upon-Avon, Miss. Montague (blue) ...
# 33745  Lord Louis Mountbatten (Hugh Bonneville) arriv...
#
#                                        DirectorCorrected  \
# 33616  director: jim o'hanlon,jim o'hanlon,: jim o'ha...
# 33617  steve mcqueen,director: steve mcqueen,: steve ...
# 33619  director: johannes roberts,johannes roberts,er...
# 33620  stephan elliott,director: stephan elliott,: st...
# 33621  director: j. a. bayona,a monster calls,: j. a....
# ...                                                  ...
# 33740  director: david yates,david yates,: david yate...
# 33741  david mackenzie,director: david mackenzie,: da...
# 33742  director: philipp stölzl,philipp stölzl,: phil...
# 33743  director: kelly asbury,kelly asbury,: kelly as...
# 33745  hugh bonneville,director: gurinder chadha,mani...
#
#                                            CastCorrected GenreCorrected
# 33616   idris elba,gemma arterton,kierston wareing,ch...
# 33617  paul dano,alfre woodard,sarah paulson,benedict...
# 33619  santiago segura, johannes roberts,matthew modi...
# 33620  kris marshall,xavier samuel,kevin bishop,rebel...
# 33621       sigourney weaver,j. a. bayona,felicity jones
# ...                                                  ...            ...
# 33740  jason isaacs,daniel radcliffe,fiona shaw,imeld...
# 33741                            eva green,ewan mcgregor
# 33742  liana liberato,garrick hagon,olga kurylenko,aa...
# 33743  maggie smith,matt lucas,dolly parton,ozzy osbo...
# 33745  drama,manish dayal,michael gambon,gillian ande...         ,drama
#
# [111 rows x 11 columns]

# %%
for index, row in tempData.iterrows():
    directors = row['DirectorCorrected']
    directors = directors.split('cast:')
    casts = directors[1]
    directors = directors[0]
    row['DirectorCorrected'] = directors
    row['CastCorrected'] = row['CastCorrected'] + ',' + casts

# %%
data = data.drop(index=tempData.index)
data = data.append(tempData, ignore_index=True)
assert data.shape[0] == 33868
data
# Out:
#        Release Year                                              Title  \
# 0            1901.0                             Kansas Saloon Smashers
# 1            1901.0                      Love by the Light of the Moon
# 2            1901.0                            The Martyred Presidents
# 3            1901.0                   Terrible Teddy, the Grizzly King
# 4            1902.0                             Jack and the Beanstalk
# ...             ...                                                ...
# 33863        2011.0  Harry Potter and the Deathly Hallows: Part 2,H...
# 33864        2010.0                        Perfect Sense,The Last Word
# 33865        2012.0                              The Expatriate,Erased
# 33866        2011.0                  Gnomeo and Juliet,Gnomeo & Juliet
# 33867        2017.0                    Gurinder Chadha,Viceroy's House
#
#         Origin/Ethnicity                                           Director  \
# 0               American                                            Unknown
# 1               American                                            Unknown
# 2               American                                            Unknown
# 3               American                                            Unknown
# 4               American                 George S. Fleming, Edwin S. Porter
# ...                  ...                                                ...
# 33863   British,American                  David Yates,Director: David Yates
# 33864            British          David Mackenzie,Director: David Mackenzie
# 33865   British,American            Philipp Stölzl,Director: Philipp Stölzl
# 33866   British,American                Kelly Asbury,Director: Kelly Asbury
# 33867  British,Bollywood  Manish Dayal,Huma Qureshi,Michael Gambon,Hugh ...
#
#                                                     Cast  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                                                unknown
# ...                                                  ...
# 33863  Robbie Coltrane,John Hurt,Julie Walters,Fiona ...
# 33864  Director: David Mackenzie Cast: Eva Green,Eva ...
# 33865  Aaron Eckhart,Garrick Hagon,Alexander Fehling,...
# 33866  Hulk Hogan,Maggie Smith,Emily Blunt,Matt Lucas...
# 33867  Manish Dayal,Huma Qureshi,Drama,David Hayman,D...
#
#                                   Genre  \
# 0                               unknown
# 1                               unknown
# 2                               unknown
# 3                               unknown
# 4                               unknown
# ...                                 ...
# 33863  action-adventure,unknown,fantasy
# 33864                           unknown
# 33865                  unknown,thriller
# 33866           unknown,family,animated
# 33867                 unknown,bbc films
#
#                                                Wiki Page  \
# 0      https://en.wikipedia.org/wiki/Kansas_Saloon_Sm...
# 1      https://en.wikipedia.org/wiki/Love_by_the_Ligh...
# 2      https://en.wikipedia.org/wiki/The_Martyred_Pre...
# 3      https://en.wikipedia.org/wiki/Terrible_Teddy,_...
# 4      https://en.wikipedia.org/wiki/Jack_and_the_Bea...
# ...                                                  ...
# 33863                                                NaN
# 33864                                                NaN
# 33865                                                NaN
# 33866                                                NaN
# 33867                                                NaN
#
#                                                     Plot  \
# 0      A bartender is working at a saloon, serving dr...
# 1      The moon, painted with a smiling face hangs ov...
# 2      The film, just over a minute long, is composed...
# 3      Lasting just 61 seconds and consisting of two ...
# 4      The earliest known adaptation of the classic f...
# ...                                                  ...
# 33863  After burying Dobby, Harry Potter asks the gob...
# 33864  An epidemic begins to spread throughout the gl...
# 33865  Ben Logan is an American single parent who has...
# 33866  In Stratford-Upon-Avon, Miss. Montague (blue) ...
# 33867  Lord Louis Mountbatten (Hugh Bonneville) arriv...
#
#                                        DirectorCorrected  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                     george s. fleming, edwin s. porter
# ...                                                  ...
# 33863  director: david yates,david yates,: david yate...
# 33864  david mackenzie,director: david mackenzie,: da...
# 33865  director: philipp stölzl,philipp stölzl,: phil...
# 33866  director: kelly asbury,kelly asbury,: kelly as...
# 33867  hugh bonneville,director: gurinder chadha,mani...
#
#                                            CastCorrected GenreCorrected
# 0                                               unknown,       ,unknown
# 1                                               unknown,       ,unknown
# 2                                               unknown,       ,unknown
# 3                                               unknown,       ,unknown
# 4                                               unknown,       ,unknown
# ...                                                  ...            ...
# 33863  jason isaacs,daniel radcliffe,fiona shaw,imeld...
# 33864                            eva green,ewan mcgregor
# 33865  liana liberato,garrick hagon,olga kurylenko,aa...
# 33866  maggie smith,matt lucas,dolly parton,ozzy osbo...
# 33867  drama,manish dayal,michael gambon,gillian ande...         ,drama
#
# [33868 rows x 11 columns]

# %%
data['DirectorCorrected'] = data['DirectorCorrected'].apply(lambda x: str(x).replace('director:', ''))
data['DirectorCorrected'] = data['DirectorCorrected'].apply(lambda x: str(x).replace('directors:', ''))

# %% [markdown]
# Теперь уберем цифры

# %%
data['CastCorrected'] = data['CastCorrected'].apply(lambda x : x.replace('cast:', ''))

# %%
def removeTrash(row:str):
    row = re.sub('[0-9]+', '', row)

    row = row.replace('&',',')
    row = row.replace(';',',')
    row = row.replace(':',',')

    row = re.sub('\[[a-z \-]*\]', '', row)
    row = re.sub('\([a-z \-]*\)', '', row)
    row = re.sub('-+', '-', row)

    return row

# %%
data['DirectorCorrected'] = data['DirectorCorrected'].apply(removeTrash)
data['CastCorrected'] = data['CastCorrected'].apply(removeTrash)

# %% [markdown]
# ### Финальные правки

# %%
data['DirectorCorrected'] = data['DirectorCorrected'].apply(correctWithSor)
data['CastCorrected'] = data['CastCorrected'].apply(correctWithSor)
data['GenreCorrected'] = data['GenreCorrected'].apply(correctWithSor)
